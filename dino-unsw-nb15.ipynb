# %% [markdown]
# DINO (Self-Distillation with No Labels)

# %% [markdown]
# Data Loading Preprocessing

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# Load dataset
train = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.parquet")
test = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.parquet")
df = pd.concat([train, test])
df = df.drop(columns=['id', 'attack_cat'], errors='ignore')

# Preprocessing: Encode categorical columns
cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    df[col] = pd.factorize(df[col])[0]

X = df.drop('label', axis=1)
y = df['label']

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)
# Out:
# 2025-06-21 08:07:08.163923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750493228.381961      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750493228.441356      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# Define DINO Model Components

# %%
def build_encoder(input_dim):
    """Builds the encoder network for DINO."""
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)  # Projection head
    return models.Model(inputs, projection)

def momentum_update(student_encoder, teacher_encoder, m=0.99):
    """Momentum update for the teacher model."""
    for student_var, teacher_var in zip(student_encoder.variables, teacher_encoder.variables):
        teacher_var.assign(m * teacher_var + (1 - m) * student_var)

def contrastive_loss(query, key, temperature=0.07):
    """Contrastive loss function used in DINO."""
    query = tf.math.l2_normalize(query, axis=1)
    key = tf.math.l2_normalize(key, axis=1)

    logits = tf.matmul(query, key, transpose_b=True) / temperature
    labels = tf.zeros(logits.shape[0], dtype=tf.int32)  # Positive pairs are the first in the logits

    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, logits)
    return tf.reduce_mean(loss)

def augment_batch(X):
    """Augmentation function: add noise and apply masking."""
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

# %% [markdown]
# Training DINO with Multiple Train-Test Ratios

# %%
ratios = [(10, 90), (20, 80), (30, 70), (40, 60), (50, 50), (60, 40), (70, 30), (80, 20), (90, 10)]
all_results = []

for train_pct, test_pct in ratios:
    print(f"\n--- Train:Test = {train_pct}:{test_pct} ---")

    # Split data according to the ratio
    X_train, X_test, y_train, y_test = train_test_split(
        X.values.astype(np.float32), y.values,
        test_size=test_pct / 100,
        stratify=y,
        random_state=42
    )

    # Initialize encoders and optimizer
    student_encoder = build_encoder(X_train.shape[1])
    teacher_encoder = build_encoder(X_train.shape[1])

    # Initialize teacher encoder weights with student encoder weights (momentum update)
    for s_var, t_var in zip(student_encoder.variables, teacher_encoder.variables):
        t_var.assign(s_var)

    optimizer = tf.keras.optimizers.Adam(3e-4)
    batch_size = 512
    epochs = 20
    num_samples = X_train.shape[0]

    for epoch in range(epochs):
        idx = np.random.permutation(num_samples)
        X_shuffled = X_train[idx]

        for i in range(0, num_samples, batch_size):
            batch = X_shuffled[i:i + batch_size]
            if batch.shape[0] < 2:
                continue

            x_q = augment_batch(batch)
            x_k = augment_batch(batch)

            with tf.GradientTape() as tape:
                z_q = student_encoder(x_q, training=True)
                z_k = teacher_encoder(x_k, training=True)
                loss = contrastive_loss(z_q, z_k)

            grads = tape.gradient(loss, student_encoder.trainable_variables)
            optimizer.apply_gradients(zip(grads, student_encoder.trainable_variables))

            # Momentum update of teacher
            momentum_update(student_encoder, teacher_encoder)

        print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss.numpy():.4f}")

        # Evaluate the model (Random Forest classifier on SSL embeddings)
        X_train_ssl = student_encoder.predict(X_train)
        X_test_ssl = student_encoder.predict(X_test)

        rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
        rf.fit(X_train_ssl, y_train)
        y_pred = rf.predict(X_test_ssl)
        report = classification_report(y_test, y_pred, output_dict=True)

        acc = report['accuracy']
        f1_0 = report['0']['f1-score']
        f1_1 = report['1']['f1-score']

        all_results.append({
            'train_pct': train_pct,
            'test_pct': test_pct,
            'epoch': epoch + 1,
            'loss': float(loss.numpy()),
            'accuracy': acc,
            'f1_class_0': f1_0,
            'f1_class_1': f1_1
        })

        print(f"Accuracy: {acc:.4f}, F1 Class 0: {f1_0:.4f}, F1 Class 1: {f1_1:.4f}")

results_df = pd.DataFrame(all_results)
results_df.to_csv('dino_results_all_epochs.csv', index=False)
print("\nSaved results to 'dino_results_all_epochs.csv'")
# Out:
# --- Train:Test = 10:90 ---
# I0000 00:00:1750493252.752713      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1750493252.753393      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/20, Loss: 7.5689
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750493258.999408     104 service.cc:148] XLA service 0x7a32e0007aa0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750493259.000122     104 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750493259.000140     104 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750493259.073374     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 135/806 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# I0000 00:00:1750493259.352880     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8989, F1 Class 0: 0.8539, F1 Class 1: 0.9227
# Epoch 2/20, Loss: 8.2648
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8992, F1 Class 0: 0.8544, F1 Class 1: 0.9229
# Epoch 3/20, Loss: 7.0314
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8990, F1 Class 0: 0.8543, F1 Class 1: 0.9227
# Epoch 4/20, Loss: 6.7863
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8988, F1 Class 0: 0.8542, F1 Class 1: 0.9225
# Epoch 5/20, Loss: 5.7865
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8993, F1 Class 0: 0.8548, F1 Class 1: 0.9229
# Epoch 6/20, Loss: 5.9924
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8966, F1 Class 0: 0.8504, F1 Class 1: 0.9210
# Epoch 7/20, Loss: 7.2703
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8959, F1 Class 0: 0.8496, F1 Class 1: 0.9204
# Epoch 8/20, Loss: 7.1681
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8959, F1 Class 0: 0.8494, F1 Class 1: 0.9204
# Epoch 9/20, Loss: 7.7698
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8962, F1 Class 0: 0.8501, F1 Class 1: 0.9206
# Epoch 10/20, Loss: 8.1221
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8964, F1 Class 0: 0.8502, F1 Class 1: 0.9209
# Epoch 11/20, Loss: 5.9471
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8969, F1 Class 0: 0.8510, F1 Class 1: 0.9212
# Epoch 12/20, Loss: 6.7911
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8961, F1 Class 0: 0.8502, F1 Class 1: 0.9205
# Epoch 13/20, Loss: 7.4742
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8944, F1 Class 0: 0.8474, F1 Class 1: 0.9193
# Epoch 14/20, Loss: 9.0560
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8949, F1 Class 0: 0.8479, F1 Class 1: 0.9197
# Epoch 15/20, Loss: 10.0999
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8932, F1 Class 0: 0.8457, F1 Class 1: 0.9183
# Epoch 16/20, Loss: 9.5623
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8936, F1 Class 0: 0.8459, F1 Class 1: 0.9188
# Epoch 17/20, Loss: 9.9859
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8924, F1 Class 0: 0.8443, F1 Class 1: 0.9178
# Epoch 18/20, Loss: 10.1098
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8932, F1 Class 0: 0.8451, F1 Class 1: 0.9185
# Epoch 19/20, Loss: 10.9463
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8923, F1 Class 0: 0.8447, F1 Class 1: 0.9176
# Epoch 20/20, Loss: 9.0273
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8909, F1 Class 0: 0.8424, F1 Class 1: 0.9165
#
# --- Train:Test = 20:80 ---
# Epoch 1/20, Loss: 7.6299
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9024, F1 Class 0: 0.8595, F1 Class 1: 0.9253
# Epoch 2/20, Loss: 7.4788
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9013, F1 Class 0: 0.8579, F1 Class 1: 0.9244
# Epoch 3/20, Loss: 7.5445
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9013, F1 Class 0: 0.8582, F1 Class 1: 0.9243
# Epoch 4/20, Loss: 6.5596
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9017, F1 Class 0: 0.8586, F1 Class 1: 0.9247
# Epoch 5/20, Loss: 6.6631
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9005, F1 Class 0: 0.8572, F1 Class 1: 0.9237
# Epoch 6/20, Loss: 10.0301
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8988, F1 Class 0: 0.8548, F1 Class 1: 0.9224
# Epoch 7/20, Loss: 9.3637
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8990, F1 Class 0: 0.8547, F1 Class 1: 0.9226
# Epoch 8/20, Loss: 9.4507
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8994, F1 Class 0: 0.8551, F1 Class 1: 0.9230
# Epoch 9/20, Loss: 9.5840
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8969, F1 Class 0: 0.8514, F1 Class 1: 0.9211
# Epoch 10/20, Loss: 13.5437
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8938, F1 Class 0: 0.8474, F1 Class 1: 0.9185
# Epoch 11/20, Loss: 13.7314
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8942, F1 Class 0: 0.8480, F1 Class 1: 0.9188
# Epoch 12/20, Loss: 12.9295
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8948, F1 Class 0: 0.8489, F1 Class 1: 0.9194
# Epoch 13/20, Loss: 11.8059
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8968, F1 Class 0: 0.8516, F1 Class 1: 0.9209
# Epoch 14/20, Loss: 11.9595
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8979, F1 Class 0: 0.8533, F1 Class 1: 0.9217
# Epoch 15/20, Loss: 8.6332
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8989, F1 Class 0: 0.8549, F1 Class 1: 0.9224
# Epoch 16/20, Loss: 6.0990
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8954, F1 Class 0: 0.8496, F1 Class 1: 0.9198
# Epoch 17/20, Loss: 6.2259
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8951, F1 Class 0: 0.8491, F1 Class 1: 0.9196
# Epoch 18/20, Loss: 5.8085
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8947, F1 Class 0: 0.8486, F1 Class 1: 0.9193
# Epoch 19/20, Loss: 5.8026
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8954, F1 Class 0: 0.8497, F1 Class 1: 0.9197
# Epoch 20/20, Loss: 5.7931
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8951, F1 Class 0: 0.8491, F1 Class 1: 0.9196
#
# --- Train:Test = 30:70 ---
# Epoch 1/20, Loss: 7.6629
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9044, F1 Class 0: 0.8625, F1 Class 1: 0.9267
# Epoch 2/20, Loss: 7.4615
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9040, F1 Class 0: 0.8624, F1 Class 1: 0.9263
# Epoch 3/20, Loss: 7.4577
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8991, F1 Class 0: 0.8551, F1 Class 1: 0.9227
# Epoch 4/20, Loss: 9.5865
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9013, F1 Class 0: 0.8581, F1 Class 1: 0.9243
# Epoch 5/20, Loss: 12.6041
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8999, F1 Class 0: 0.8563, F1 Class 1: 0.9232
# Epoch 6/20, Loss: 10.4759
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9009, F1 Class 0: 0.8578, F1 Class 1: 0.9240
# Epoch 7/20, Loss: 13.3918
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9015, F1 Class 0: 0.8586, F1 Class 1: 0.9244
# Epoch 8/20, Loss: 14.4734
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8987, F1 Class 0: 0.8544, F1 Class 1: 0.9223
# Epoch 9/20, Loss: 14.5051
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8980, F1 Class 0: 0.8533, F1 Class 1: 0.9218
# Epoch 10/20, Loss: 12.5336
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8995, F1 Class 0: 0.8554, F1 Class 1: 0.9230
# Epoch 11/20, Loss: 7.3922
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8992, F1 Class 0: 0.8549, F1 Class 1: 0.9228
# Epoch 12/20, Loss: 6.4173
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9009, F1 Class 0: 0.8578, F1 Class 1: 0.9240
# Epoch 13/20, Loss: 6.2409
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9003, F1 Class 0: 0.8569, F1 Class 1: 0.9235
# Epoch 14/20, Loss: 6.1854
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9003, F1 Class 0: 0.8566, F1 Class 1: 0.9236
# Epoch 15/20, Loss: 6.2353
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9002, F1 Class 0: 0.8565, F1 Class 1: 0.9235
# Epoch 16/20, Loss: 6.2041
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9005, F1 Class 0: 0.8571, F1 Class 1: 0.9237
# Epoch 17/20, Loss: 6.2062
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9005, F1 Class 0: 0.8569, F1 Class 1: 0.9238
# Epoch 18/20, Loss: 6.2048
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9000, F1 Class 0: 0.8563, F1 Class 1: 0.9234
# Epoch 19/20, Loss: 6.2190
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9003, F1 Class 0: 0.8565, F1 Class 1: 0.9236
# Epoch 20/20, Loss: 6.2131
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8998, F1 Class 0: 0.8557, F1 Class 1: 0.9232
#
# --- Train:Test = 40:60 ---
# Epoch 1/20, Loss: 8.1299
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9097, F1 Class 0: 0.8712, F1 Class 1: 0.9304
# Epoch 2/20, Loss: 7.8783
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9060, F1 Class 0: 0.8652, F1 Class 1: 0.9279
# Epoch 3/20, Loss: 7.8943
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9041, F1 Class 0: 0.8626, F1 Class 1: 0.9264
# Epoch 4/20, Loss: 10.6393
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9033, F1 Class 0: 0.8616, F1 Class 1: 0.9257
# Epoch 5/20, Loss: 9.6588
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9020, F1 Class 0: 0.8590, F1 Class 1: 0.9250
# Epoch 6/20, Loss: 9.5713
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9028, F1 Class 0: 0.8603, F1 Class 1: 0.9255
# Epoch 7/20, Loss: 12.9631
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9034, F1 Class 0: 0.8616, F1 Class 1: 0.9258
# Epoch 8/20, Loss: 6.1532
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9013, F1 Class 0: 0.8581, F1 Class 1: 0.9243
# Epoch 9/20, Loss: 5.1666
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9017, F1 Class 0: 0.8586, F1 Class 1: 0.9247
# Epoch 10/20, Loss: 5.0302
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9018, F1 Class 0: 0.8588, F1 Class 1: 0.9247
# Epoch 11/20, Loss: 5.0545
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9010, F1 Class 0: 0.8576, F1 Class 1: 0.9241
# Epoch 12/20, Loss: 5.0615
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9011, F1 Class 0: 0.8577, F1 Class 1: 0.9242
# Epoch 13/20, Loss: 5.0597
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9016, F1 Class 0: 0.8585, F1 Class 1: 0.9245
# Epoch 14/20, Loss: 5.0488
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9013, F1 Class 0: 0.8580, F1 Class 1: 0.9244
# Epoch 15/20, Loss: 5.0513
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9015, F1 Class 0: 0.8584, F1 Class 1: 0.9245
# Epoch 16/20, Loss: 5.0377
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9011, F1 Class 0: 0.8577, F1 Class 1: 0.9242
# Epoch 17/20, Loss: 5.0516
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9015, F1 Class 0: 0.8582, F1 Class 1: 0.9245
# Epoch 18/20, Loss: 5.0434
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9016, F1 Class 0: 0.8584, F1 Class 1: 0.9247
# Epoch 19/20, Loss: 5.0412
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9011, F1 Class 0: 0.8576, F1 Class 1: 0.9243
# Epoch 20/20, Loss: 5.0403
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9014, F1 Class 0: 0.8581, F1 Class 1: 0.9245
#
# --- Train:Test = 50:50 ---
# Epoch 1/20, Loss: 7.4230
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9093, F1 Class 0: 0.8704, F1 Class 1: 0.9302
# Epoch 2/20, Loss: 9.7901
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9074, F1 Class 0: 0.8673, F1 Class 1: 0.9289
# Epoch 3/20, Loss: 8.4579
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9053, F1 Class 0: 0.8641, F1 Class 1: 0.9273
# Epoch 4/20, Loss: 11.5020
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9034, F1 Class 0: 0.8616, F1 Class 1: 0.9258
# Epoch 5/20, Loss: 10.8361
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9041, F1 Class 0: 0.8629, F1 Class 1: 0.9263
# Epoch 6/20, Loss: 11.4359
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9049, F1 Class 0: 0.8647, F1 Class 1: 0.9267
# Epoch 7/20, Loss: 6.6442
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9044, F1 Class 0: 0.8639, F1 Class 1: 0.9264
# Epoch 8/20, Loss: 5.8809
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9046, F1 Class 0: 0.8640, F1 Class 1: 0.9265
# Epoch 9/20, Loss: 5.7687
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9048, F1 Class 0: 0.8643, F1 Class 1: 0.9266
# Epoch 10/20, Loss: 5.8059
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9044, F1 Class 0: 0.8637, F1 Class 1: 0.9263
# Epoch 11/20, Loss: 5.7570
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9045, F1 Class 0: 0.8640, F1 Class 1: 0.9264
# Epoch 12/20, Loss: 5.7677
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9044, F1 Class 0: 0.8638, F1 Class 1: 0.9263
# Epoch 13/20, Loss: 5.7735
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9045, F1 Class 0: 0.8640, F1 Class 1: 0.9264
# Epoch 14/20, Loss: 5.7670
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9042, F1 Class 0: 0.8635, F1 Class 1: 0.9262
# Epoch 15/20, Loss: 5.7661
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9041, F1 Class 0: 0.8633, F1 Class 1: 0.9261
# Epoch 16/20, Loss: 5.7780
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9050, F1 Class 0: 0.8646, F1 Class 1: 0.9268
# Epoch 17/20, Loss: 6.0359
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9058, F1 Class 0: 0.8658, F1 Class 1: 0.9274
# Epoch 18/20, Loss: 5.7646
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8652, F1 Class 1: 0.9272
# Epoch 19/20, Loss: 5.7990
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9052, F1 Class 0: 0.8649, F1 Class 1: 0.9270
# Epoch 20/20, Loss: 5.8490
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9049, F1 Class 0: 0.8644, F1 Class 1: 0.9268
#
# --- Train:Test = 60:40 ---
# Epoch 1/20, Loss: 9.3467
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9082, F1 Class 0: 0.8683, F1 Class 1: 0.9295
# Epoch 2/20, Loss: 8.6880
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9059, F1 Class 0: 0.8648, F1 Class 1: 0.9278
# Epoch 3/20, Loss: 9.6391
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9062, F1 Class 0: 0.8658, F1 Class 1: 0.9278
# Epoch 4/20, Loss: 11.5380
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9062, F1 Class 0: 0.8655, F1 Class 1: 0.9280
# Epoch 5/20, Loss: 7.2985
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9072, F1 Class 0: 0.8674, F1 Class 1: 0.9286
# Epoch 6/20, Loss: 6.2313
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9069, F1 Class 0: 0.8671, F1 Class 1: 0.9284
# Epoch 7/20, Loss: 6.1974
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9079, F1 Class 0: 0.8683, F1 Class 1: 0.9292
# Epoch 8/20, Loss: 6.1995
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9070, F1 Class 0: 0.8671, F1 Class 1: 0.9285
# Epoch 9/20, Loss: 6.1899
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9072, F1 Class 0: 0.8674, F1 Class 1: 0.9287
# Epoch 10/20, Loss: 6.1910
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9066, F1 Class 0: 0.8666, F1 Class 1: 0.9281
# Epoch 11/20, Loss: 6.2003
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9072, F1 Class 0: 0.8673, F1 Class 1: 0.9287
# Epoch 12/20, Loss: 6.1908
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8671, F1 Class 1: 0.9286
# Epoch 13/20, Loss: 6.1804
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9074, F1 Class 0: 0.8676, F1 Class 1: 0.9288
# Epoch 14/20, Loss: 6.1842
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9077, F1 Class 0: 0.8682, F1 Class 1: 0.9290
# Epoch 15/20, Loss: 6.1887
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8676, F1 Class 1: 0.9287
# Epoch 16/20, Loss: 6.1874
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9087, F1 Class 0: 0.8696, F1 Class 1: 0.9298
# Epoch 17/20, Loss: 6.1826
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9075, F1 Class 0: 0.8680, F1 Class 1: 0.9288
# Epoch 18/20, Loss: 6.1945
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9079, F1 Class 0: 0.8684, F1 Class 1: 0.9292
# Epoch 19/20, Loss: 6.1844
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9074, F1 Class 0: 0.8676, F1 Class 1: 0.9287
# Epoch 20/20, Loss: 6.1891
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9067, F1 Class 0: 0.8667, F1 Class 1: 0.9283
#
# --- Train:Test = 70:30 ---
# Epoch 1/20, Loss: 6.1581
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9103, F1 Class 0: 0.8716, F1 Class 1: 0.9311
# Epoch 2/20, Loss: 8.8813
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9102, F1 Class 0: 0.8718, F1 Class 1: 0.9309
# Epoch 3/20, Loss: 11.0680
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8672, F1 Class 1: 0.9288
# Epoch 4/20, Loss: 10.0797
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9068, F1 Class 0: 0.8665, F1 Class 1: 0.9285
# Epoch 5/20, Loss: 5.1049
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8669, F1 Class 1: 0.9289
# Epoch 6/20, Loss: 4.9906
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9069, F1 Class 0: 0.8664, F1 Class 1: 0.9286
# Epoch 7/20, Loss: 4.9675
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8666, F1 Class 1: 0.9287
# Epoch 8/20, Loss: 4.9793
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9068, F1 Class 0: 0.8662, F1 Class 1: 0.9285
# Epoch 9/20, Loss: 4.9686
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9070, F1 Class 0: 0.8665, F1 Class 1: 0.9287
# Epoch 10/20, Loss: 5.1061
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9074, F1 Class 0: 0.8672, F1 Class 1: 0.9289
# Epoch 11/20, Loss: 4.9881
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8673, F1 Class 1: 0.9291
# Epoch 12/20, Loss: 4.9754
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8672, F1 Class 1: 0.9291
# Epoch 13/20, Loss: 4.9847
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8672, F1 Class 1: 0.9291
# Epoch 14/20, Loss: 4.9810
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8669, F1 Class 1: 0.9289
# Epoch 15/20, Loss: 4.9913
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9072, F1 Class 0: 0.8668, F1 Class 1: 0.9288
# Epoch 16/20, Loss: 4.9842
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8668, F1 Class 1: 0.9289
# Epoch 17/20, Loss: 4.9813
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9074, F1 Class 0: 0.8670, F1 Class 1: 0.9290
# Epoch 18/20, Loss: 4.9714
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9069, F1 Class 0: 0.8662, F1 Class 1: 0.9286
# Epoch 19/20, Loss: 5.0037
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9066, F1 Class 0: 0.8657, F1 Class 1: 0.9284
# Epoch 20/20, Loss: 4.9731
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8665, F1 Class 1: 0.9288
#
# --- Train:Test = 80:20 ---
# Epoch 1/20, Loss: 7.9695
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9133, F1 Class 0: 0.8771, F1 Class 1: 0.9331
# Epoch 2/20, Loss: 9.5368
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9104, F1 Class 0: 0.8717, F1 Class 1: 0.9312
# Epoch 3/20, Loss: 11.6333
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9103, F1 Class 0: 0.8720, F1 Class 1: 0.9310
# Epoch 4/20, Loss: 5.7399
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9111, F1 Class 0: 0.8737, F1 Class 1: 0.9315
# Epoch 5/20, Loss: 5.7168
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9097, F1 Class 0: 0.8714, F1 Class 1: 0.9304
# Epoch 6/20, Loss: 5.7357
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9092, F1 Class 0: 0.8708, F1 Class 1: 0.9300
# Epoch 7/20, Loss: 5.7515
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9102, F1 Class 0: 0.8721, F1 Class 1: 0.9308
# Epoch 8/20, Loss: 5.7606
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9090, F1 Class 0: 0.8704, F1 Class 1: 0.9299
# Epoch 9/20, Loss: 5.7406
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9086, F1 Class 0: 0.8700, F1 Class 1: 0.9295
# Epoch 10/20, Loss: 5.7358
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9090, F1 Class 0: 0.8706, F1 Class 1: 0.9299
# Epoch 11/20, Loss: 5.7285
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9089, F1 Class 0: 0.8705, F1 Class 1: 0.9297
# Epoch 12/20, Loss: 5.7699
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9094, F1 Class 0: 0.8710, F1 Class 1: 0.9302
# Epoch 13/20, Loss: 5.7364
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9088, F1 Class 0: 0.8703, F1 Class 1: 0.9297
# Epoch 14/20, Loss: 5.7479
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9088, F1 Class 0: 0.8703, F1 Class 1: 0.9297
# Epoch 15/20, Loss: 5.7551
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8708, F1 Class 1: 0.9299
# Epoch 16/20, Loss: 5.7349
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9100, F1 Class 0: 0.8718, F1 Class 1: 0.9306
# Epoch 17/20, Loss: 5.8935
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9103, F1 Class 0: 0.8724, F1 Class 1: 0.9309
# Epoch 18/20, Loss: 5.7489
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9092, F1 Class 0: 0.8710, F1 Class 1: 0.9300
# Epoch 19/20, Loss: 5.7337
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8704, F1 Class 1: 0.9299
# Epoch 20/20, Loss: 5.7430
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8705, F1 Class 1: 0.9299
#
# --- Train:Test = 90:10 ---
# Epoch 1/20, Loss: 8.3780
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9129, F1 Class 0: 0.8761, F1 Class 1: 0.9329
# Epoch 2/20, Loss: 11.7926
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9119, F1 Class 0: 0.8739, F1 Class 1: 0.9323
# Epoch 3/20, Loss: 11.2716
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9086, F1 Class 0: 0.8692, F1 Class 1: 0.9298
# Epoch 4/20, Loss: 6.2781
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9093, F1 Class 0: 0.8701, F1 Class 1: 0.9303
# Epoch 5/20, Loss: 6.1637
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9078, F1 Class 0: 0.8677, F1 Class 1: 0.9292
# Epoch 6/20, Loss: 6.1734
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8669, F1 Class 1: 0.9287
# Epoch 7/20, Loss: 6.1605
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9079, F1 Class 0: 0.8678, F1 Class 1: 0.9294
# Epoch 8/20, Loss: 6.1648
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9090, F1 Class 0: 0.8693, F1 Class 1: 0.9301
# Epoch 9/20, Loss: 6.1730
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9075, F1 Class 0: 0.8675, F1 Class 1: 0.9289
# Epoch 10/20, Loss: 6.1685
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8668, F1 Class 1: 0.9289
# Epoch 11/20, Loss: 6.1669
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8667, F1 Class 1: 0.9287
# Epoch 12/20, Loss: 6.1742
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9079, F1 Class 0: 0.8678, F1 Class 1: 0.9293
# Epoch 13/20, Loss: 6.1681
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9075, F1 Class 0: 0.8674, F1 Class 1: 0.9290
# Epoch 14/20, Loss: 6.1656
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9079, F1 Class 0: 0.8678, F1 Class 1: 0.9294
# Epoch 15/20, Loss: 6.1661
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9079, F1 Class 0: 0.8678, F1 Class 1: 0.9293
# Epoch 16/20, Loss: 6.1688
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9070, F1 Class 0: 0.8664, F1 Class 1: 0.9287
# Epoch 17/20, Loss: 6.4301
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9068, F1 Class 0: 0.8662, F1 Class 1: 0.9285
# Epoch 18/20, Loss: 6.1743
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8675, F1 Class 1: 0.9291
# Epoch 19/20, Loss: 6.1660
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9086, F1 Class 0: 0.8689, F1 Class 1: 0.9299
# Epoch 20/20, Loss: 6.1557
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9100, F1 Class 0: 0.8709, F1 Class 1: 0.9309
#
# Saved results to 'dino_results_all_epochs.csv'

# %%
# Set style for plots
import seaborn as sns
sns.set(style="whitegrid")
ratios_unique = results_df[['train_pct', 'test_pct']].drop_duplicates()

# Accuracy vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['accuracy'], marker='o', label=label)
plt.title("Accuracy vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()

# %%
# Loss vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['loss'], marker='o', label=label)
plt.title("Contrastive Loss vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()
