# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import joblib
import os
import matplotlib.pyplot as plt

# ======================
# 1. Load and Preprocess Data
# ======================
def load_and_preprocess():
    # Load data
    train = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.parquet")
    test = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.parquet")
    df = pd.concat([train, test])
    
    # Preprocessing
    df = df.drop(columns=['id', 'attack_cat'], errors='ignore')
    cat_cols = ['proto', 'service', 'state']
    for col in cat_cols:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
    
    X = df.drop('label', axis=1)
    y = df['label']
    
    # Scale numerical features
    num_cols = X.select_dtypes(include=[np.number]).columns
    scaler = StandardScaler()
    X[num_cols] = scaler.fit_transform(X[num_cols])
    
    return X, y

X, y = load_and_preprocess()

# %%
# ======================
# 2. Experiment Setup
# ======================
ratios = [
    (10, 90), (20, 80), (30, 70), 
    (40, 60), (50, 50), (60, 40),
    (70, 30), (80, 20), (90, 10)
]

results = {}
os.makedirs('saved_models', exist_ok=True)

# %% [markdown]
# Random Forest

# %%
# ======================
# 3. Training and Evaluation(Random Forest)
# ======================
for train_ratio, test_ratio in ratios:
    print(f"\n=== Training with {train_ratio}:{test_ratio} split ===")
    
    # Split data (stratified for labeled portion)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, 
        test_size=test_ratio/100, 
        stratify=y,
        random_state=42
    )
    
    # Train Random Forest
    rf = RandomForestClassifier(
        n_estimators=100,
        class_weight='balanced',
        random_state=42,
        n_jobs=-1
    )
    rf.fit(X_train, y_train)
    
    # Evaluate
    y_pred = rf.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    
    # Store results
    results[f"{train_ratio}:{test_ratio}"] = {
        'model': rf,
        'accuracy': report['accuracy'],
        'precision_0': report['0']['precision'],
        'recall_0': report['0']['recall'],
        'f1_0': report['0']['f1-score'],
        'precision_1': report['1']['precision'],
        'recall_1': report['1']['recall'],
        'f1_1': report['1']['f1-score']
    }
    
    # Save model
    joblib.dump(rf, f'saved_models/rf_{train_ratio}_{test_ratio}.joblib')
    print(f"Model saved for {train_ratio}:{test_ratio} split")
# Out:
# === Training with 10:90 split ===
# Model saved for 10:90 split
#
# === Training with 20:80 split ===
# Model saved for 20:80 split
#
# === Training with 30:70 split ===
# Model saved for 30:70 split
#
# === Training with 40:60 split ===
# Model saved for 40:60 split
#
# === Training with 50:50 split ===
# Model saved for 50:50 split
#
# === Training with 60:40 split ===
# Model saved for 60:40 split
#
# === Training with 70:30 split ===
# Model saved for 70:30 split
#
# === Training with 80:20 split ===
# Model saved for 80:20 split
#
# === Training with 90:10 split ===
# Model saved for 90:10 split

# %%
# ======================
# 4. Results Analysis
# ======================
# Create results dataframe
results_df = pd.DataFrame.from_dict(results, orient='index')

# Save results to CSV
results_df.to_csv('/kaggle/working/model_results.csv')
print("\nResults saved to model_results.csv")

# Save models and results in Kaggle's working directory
os.makedirs('/kaggle/working/saved_models', exist_ok=True)
for ratio, result in results.items():
    train_ratio = ratio.split(':')[0]
    joblib.dump(result['model'], f'/kaggle/working/saved_models/rf_{train_ratio}.joblib')

# Create zip archive of results
import zipfile
with zipfile.ZipFile('/kaggle/working/models_and_results.zip', 'w') as zipf:
    zipf.write('/kaggle/working/model_results.csv')
    for file in os.listdir('/kaggle/working/saved_models'):
        zipf.write(f'/kaggle/working/saved_models/{file}')
# Out:
# Results saved to model_results.csv

# %%
# ======================
# 5. Visualization
# ======================
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
results_df['accuracy'].plot(kind='bar', color='skyblue')
plt.title('Accuracy Across Splits')
plt.ylabel('Accuracy')
plt.ylim(0.7, 1.0)

# F1-Score comparison
plt.subplot(1, 2, 2)
results_df[['f1_0', 'f1_1']].plot(kind='bar', color=['lightgreen', 'salmon'])
plt.title('F1-Scores by Class')
plt.ylabel('F1 Score')
plt.legend(['Normal (0)', 'Attack (1)'])

plt.tight_layout()
plt.savefig('/kaggle/working/results_comparison.png')
plt.show()

# Print summary table
print("\n=== Performance Summary ===")
print(results_df[['accuracy', 'f1_0', 'f1_1']])
# Out:
# === Performance Summary ===
#        accuracy      f1_0      f1_1
# 10:90  0.927626  0.899521  0.943445
# 20:80  0.931614  0.905720  0.946349
# 30:70  0.933937  0.909045  0.948131
# 40:60  0.935636  0.911511  0.949424
# 50:50  0.937580  0.914279  0.950921
# 60:40  0.938653  0.915890  0.951720
# 70:30  0.939562  0.917131  0.952436
# 80:20  0.941535  0.919890  0.953971
# 90:10  0.942021  0.920625  0.954331

# %% [markdown]
# SSl

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
# Load your dataset
train = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.parquet")
test = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.parquet")

df = pd.concat([train, test])

# Drop unnecessary columns
df = df.drop(columns=['id', 'attack_cat'], errors='ignore')

# Encode categorical columns
cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    df[col] = pd.factorize(df[col])[0]

# Separate features and labels
X = df.drop('label', axis=1)
y = df['label']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
def build_encoder(input_dim):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)  # projection head output
    return models.Model(inputs, projection)

def contrastive_loss(z1, z2, temperature=0.1):
    z1 = tf.math.l2_normalize(z1, axis=1)
    z2 = tf.math.l2_normalize(z2, axis=1)
    sim = tf.matmul(z1, z2, transpose_b=True) / temperature
    return tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(
            logits=sim,
            labels=tf.eye(tf.shape(z1)[0])
        )
    )

# %%
def augment_batch(X):
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

# %%
# For example, use 80% train and 20% test split for now
X_train, X_test, y_train, y_test = train_test_split(
    X.values.astype(np.float32),
    y.values,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
encoder = build_encoder(X_train.shape[1])
optimizer = tf.keras.optimizers.Adam(3e-4)

# %%
batch_size = 512
epochs = 50
num_samples = X_train.shape[0]

# %%
for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    
    # Shuffle indices
    idx = np.random.permutation(num_samples)
    X_shuffled = X_train[idx]
    
    # Batch training
    for i in range(0, num_samples, batch_size):
        batch = X_shuffled[i:i+batch_size]
        if batch.shape[0] < 2:
            continue
        
        # Create two augmented views for contrastive learning
        x1 = augment_batch(batch)
        x2 = augment_batch(batch)
        
        with tf.GradientTape() as tape:
            z1 = encoder(x1, training=True)
            z2 = encoder(x2, training=True)
            loss = contrastive_loss(z1, z2)
        
        grads = tape.gradient(loss, encoder.trainable_weights)
        optimizer.apply_gradients(zip(grads, encoder.trainable_weights))
        
    print(f"Loss: {loss.numpy():.4f}")
# Out:
# Epoch 1/2
# Loss: 2.0282
# Epoch 2/2
# Loss: 1.9350

# %%
# Extract embeddings
X_train_ssl = encoder.predict(X_train)
X_test_ssl = encoder.predict(X_test)

# Train RandomForest on SSL embeddings
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_ssl, y_train)

# Evaluate
y_pred = rf.predict(X_test_ssl)
print(classification_report(y_test, y_pred))

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# Step 1: Load & preprocess data
train = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.parquet")
test = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.parquet")
df = pd.concat([train, test])
df = df.drop(columns=['id', 'attack_cat'], errors='ignore')

cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    df[col] = pd.factorize(df[col])[0]

X = df.drop('label', axis=1)
y = df['label']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)

# Step 2: Define encoder model & loss
def build_encoder(input_dim):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)
    return models.Model(inputs, projection)

def contrastive_loss(z1, z2, temperature=0.1):
    z1 = tf.math.l2_normalize(z1, axis=1)
    z2 = tf.math.l2_normalize(z2, axis=1)
    sim = tf.matmul(z1, z2, transpose_b=True) / temperature
    return tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(
            logits=sim,
            labels=tf.eye(tf.shape(z1)[0])
        )
    )

def augment_batch(X):
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

# Step 3: Train & evaluate for multiple ratios
ratios = [(10,90), (20,80), (30,70), (40,60), (50,50), (60,40), (70,30), (80,20), (90,10)]
results = []

for train_pct, test_pct in ratios:
    print(f"\n--- Training with train:test = {train_pct}:{test_pct} ---")
    
    X_train, X_test, y_train, y_test = train_test_split(
        X.values.astype(np.float32), y.values,
        test_size=test_pct/100,
        stratify=y,
        random_state=42
    )
    
    encoder = build_encoder(X_train.shape[1])
    optimizer = tf.keras.optimizers.Adam(3e-4)
    
    batch_size = 512
    epochs = 50
    num_samples = X_train.shape[0]
    
    # Custom training loop
    for epoch in range(epochs):
        idx = np.random.permutation(num_samples)
        X_shuffled = X_train[idx]
        for i in range(0, num_samples, batch_size):
            batch = X_shuffled[i:i+batch_size]
            if batch.shape[0] < 2:
                continue
            x1 = augment_batch(batch)
            x2 = augment_batch(batch)
            with tf.GradientTape() as tape:
                z1 = encoder(x1, training=True)
                z2 = encoder(x2, training=True)
                loss = contrastive_loss(z1, z2)
            grads = tape.gradient(loss, encoder.trainable_weights)
            optimizer.apply_gradients(zip(grads, encoder.trainable_weights))
        print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.numpy():.4f}")
    
    # Extract embeddings
    X_train_ssl = encoder.predict(X_train)
    X_test_ssl = encoder.predict(X_test)
    
    # Train RandomForest on embeddings
    rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
    rf.fit(X_train_ssl, y_train)
    y_pred = rf.predict(X_test_ssl)
    
    report = classification_report(y_test, y_pred, output_dict=True)
    acc = report['accuracy']
    f1_0 = report['0']['f1-score']
    f1_1 = report['1']['f1-score']
    
    results.append({
        'train_pct': train_pct,
        'test_pct': test_pct,
        'accuracy': acc,
        'f1_class_0': f1_0,
        'f1_class_1': f1_1
    })
    
    print(f"Accuracy: {acc:.4f}, F1 Class 0: {f1_0:.4f}, F1 Class 1: {f1_1:.4f}")

# Step 4: Visualize results
results_df = pd.DataFrame(results)
plt.figure(figsize=(10,6))
plt.plot(results_df['train_pct'], results_df['accuracy'], marker='o')
plt.title('Accuracy vs Training Data Percentage')
plt.xlabel('Training Data Percentage (%)')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

plt.figure(figsize=(10,6))
plt.plot(results_df['train_pct'], results_df['f1_class_0'], marker='o', label='F1 Class 0')
plt.plot(results_df['train_pct'], results_df['f1_class_1'], marker='o', label='F1 Class 1')
plt.title('F1 Scores vs Training Data Percentage')
plt.xlabel('Training Data Percentage (%)')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- Training with train:test = 10:90 ---
# Epoch 1/50, Loss: 2.1718
# Epoch 2/50, Loss: 2.0313
# Epoch 3/50, Loss: 1.9474
# Epoch 4/50, Loss: 1.8850
# Epoch 5/50, Loss: 1.8506
# Epoch 6/50, Loss: 1.5367
# Epoch 7/50, Loss: 1.5536
# Epoch 8/50, Loss: 1.7645
# Epoch 9/50, Loss: 1.4893
# Epoch 10/50, Loss: 1.6363
# Epoch 11/50, Loss: 1.6700
# Epoch 12/50, Loss: 1.5668
# Epoch 13/50, Loss: 1.6861
# Epoch 14/50, Loss: 1.4177
# Epoch 15/50, Loss: 1.4655
# Epoch 16/50, Loss: 1.5369
# Epoch 17/50, Loss: 1.3138
# Epoch 18/50, Loss: 1.4746
# Epoch 19/50, Loss: 1.6779
# Epoch 20/50, Loss: 1.5201
# Epoch 21/50, Loss: 1.5187
# Epoch 22/50, Loss: 1.4478
# Epoch 23/50, Loss: 1.6196
# Epoch 24/50, Loss: 1.3758
# Epoch 25/50, Loss: 1.5946
# Epoch 26/50, Loss: 1.5899
# Epoch 27/50, Loss: 1.4800
# Epoch 28/50, Loss: 1.2713
# Epoch 29/50, Loss: 1.4082
# Epoch 30/50, Loss: 1.4395
# Epoch 31/50, Loss: 1.3161
# Epoch 32/50, Loss: 1.5964
# Epoch 33/50, Loss: 1.5079
# Epoch 34/50, Loss: 1.2035
# Epoch 35/50, Loss: 1.4442
# Epoch 36/50, Loss: 1.4615
# Epoch 37/50, Loss: 1.5062
# Epoch 38/50, Loss: 1.6322
# Epoch 39/50, Loss: 1.4663
# Epoch 40/50, Loss: 1.4178
# Epoch 41/50, Loss: 1.2513
# Epoch 42/50, Loss: 1.3125
# Epoch 43/50, Loss: 1.5056
# Epoch 44/50, Loss: 1.5582
# Epoch 45/50, Loss: 1.2990
# Epoch 46/50, Loss: 1.3873
# Epoch 47/50, Loss: 1.6443
# Epoch 48/50, Loss: 1.5098
# Epoch 49/50, Loss: 1.6245
# Epoch 50/50, Loss: 1.2109
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9048, F1 Class 0: 0.8629, F1 Class 1: 0.9271
#
# --- Training with train:test = 20:80 ---
# Epoch 1/50, Loss: 2.5084
# Epoch 2/50, Loss: 2.4404
# Epoch 3/50, Loss: 2.2079
# Epoch 4/50, Loss: 2.2254
# Epoch 5/50, Loss: 2.1500
# Epoch 6/50, Loss: 2.2134
# Epoch 7/50, Loss: 2.1034
# Epoch 8/50, Loss: 2.2111
# Epoch 9/50, Loss: 2.0286
# Epoch 10/50, Loss: 1.9984
# Epoch 11/50, Loss: 2.0047
# Epoch 12/50, Loss: 2.0807
# Epoch 13/50, Loss: 1.9654
# Epoch 14/50, Loss: 2.0800
# Epoch 15/50, Loss: 2.0487
# Epoch 16/50, Loss: 1.9887
# Epoch 17/50, Loss: 1.9725
# Epoch 18/50, Loss: 2.0205
# Epoch 19/50, Loss: 1.6225
# Epoch 20/50, Loss: 2.0144
# Epoch 21/50, Loss: 1.7683
# Epoch 22/50, Loss: 1.6819
# Epoch 23/50, Loss: 1.7868
# Epoch 24/50, Loss: 1.8891
# Epoch 25/50, Loss: 1.7997
# Epoch 26/50, Loss: 1.9815
# Epoch 27/50, Loss: 1.7649
# Epoch 28/50, Loss: 1.9047
# Epoch 29/50, Loss: 1.8913
# Epoch 30/50, Loss: 1.8908
# Epoch 31/50, Loss: 1.7273
# Epoch 32/50, Loss: 1.7871
# Epoch 33/50, Loss: 1.8417
# Epoch 34/50, Loss: 1.8833
# Epoch 35/50, Loss: 1.6238
# Epoch 36/50, Loss: 1.8193
# Epoch 37/50, Loss: 1.7905
# Epoch 38/50, Loss: 1.8755
# Epoch 39/50, Loss: 1.8526
# Epoch 40/50, Loss: 1.7622
# Epoch 41/50, Loss: 1.7697
# Epoch 42/50, Loss: 1.7944
# Epoch 43/50, Loss: 1.8343
# Epoch 44/50, Loss: 1.8314
# Epoch 45/50, Loss: 1.8253
# Epoch 46/50, Loss: 1.7801
# Epoch 47/50, Loss: 1.6873
# Epoch 48/50, Loss: 1.7805
# Epoch 49/50, Loss: 1.6651
# Epoch 50/50, Loss: 1.7984
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8700, F1 Class 1: 0.9301
#
# --- Training with train:test = 30:70 ---
# Epoch 1/50, Loss: 2.8896
# Epoch 2/50, Loss: 2.5334
# Epoch 3/50, Loss: 2.5610
# Epoch 4/50, Loss: 2.4896
# Epoch 5/50, Loss: 2.3692
# Epoch 6/50, Loss: 2.2754
# Epoch 7/50, Loss: 2.1644
# Epoch 8/50, Loss: 2.4290
# Epoch 9/50, Loss: 2.2150
# Epoch 10/50, Loss: 2.2785
# Epoch 11/50, Loss: 2.3386
# Epoch 12/50, Loss: 2.2009
# Epoch 13/50, Loss: 2.2746
# Epoch 14/50, Loss: 2.1423
# Epoch 15/50, Loss: 2.1588
# Epoch 16/50, Loss: 2.1827
# Epoch 17/50, Loss: 2.0623
# Epoch 18/50, Loss: 2.2051
# Epoch 19/50, Loss: 2.0686
# Epoch 20/50, Loss: 2.1319
# Epoch 21/50, Loss: 2.1922
# Epoch 22/50, Loss: 2.0674
# Epoch 23/50, Loss: 2.0670
# Epoch 24/50, Loss: 2.0685
# Epoch 25/50, Loss: 2.0217
# Epoch 26/50, Loss: 2.1165
# Epoch 27/50, Loss: 2.0027
# Epoch 28/50, Loss: 2.0349
# Epoch 29/50, Loss: 2.0046
# Epoch 30/50, Loss: 1.9818
# Epoch 31/50, Loss: 2.0299
# Epoch 32/50, Loss: 2.0671
# Epoch 33/50, Loss: 2.0582
# Epoch 34/50, Loss: 1.9286
# Epoch 35/50, Loss: 2.1529
# Epoch 36/50, Loss: 2.1406
# Epoch 37/50, Loss: 2.0555
# Epoch 38/50, Loss: 2.0836
# Epoch 39/50, Loss: 1.9570
# Epoch 40/50, Loss: 1.9508
# Epoch 41/50, Loss: 1.9832
# Epoch 42/50, Loss: 1.9525
# Epoch 43/50, Loss: 1.7549
# Epoch 44/50, Loss: 1.8661
# Epoch 45/50, Loss: 2.1008
# Epoch 46/50, Loss: 2.0810
# Epoch 47/50, Loss: 2.0966
# Epoch 48/50, Loss: 1.9914
# Epoch 49/50, Loss: 1.8999
# Epoch 50/50, Loss: 1.8098
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9109, F1 Class 0: 0.8724, F1 Class 1: 0.9315
#
# --- Training with train:test = 40:60 ---
# Epoch 1/50, Loss: 1.6110
# Epoch 2/50, Loss: 1.6714
# Epoch 3/50, Loss: 1.4988
# Epoch 4/50, Loss: 1.4424
# Epoch 5/50, Loss: 1.6364
# Epoch 6/50, Loss: 1.3167
# Epoch 7/50, Loss: 1.3893
# Epoch 8/50, Loss: 1.4627
# Epoch 9/50, Loss: 1.2592
# Epoch 10/50, Loss: 1.4523
# Epoch 11/50, Loss: 1.3764
# Epoch 12/50, Loss: 1.4520
# Epoch 13/50, Loss: 1.2433
# Epoch 14/50, Loss: 1.5871
# Epoch 15/50, Loss: 1.3676
# Epoch 16/50, Loss: 1.0764
# Epoch 17/50, Loss: 1.2462
# Epoch 18/50, Loss: 1.1387
# Epoch 19/50, Loss: 1.0520
# Epoch 20/50, Loss: 1.3123
# Epoch 21/50, Loss: 1.2479
# Epoch 22/50, Loss: 1.1907
# Epoch 23/50, Loss: 1.1588
# Epoch 24/50, Loss: 1.3196
# Epoch 25/50, Loss: 1.4129
# Epoch 26/50, Loss: 0.9860
# Epoch 27/50, Loss: 1.3921
# Epoch 28/50, Loss: 1.1192
# Epoch 29/50, Loss: 1.1158
# Epoch 30/50, Loss: 1.1634
# Epoch 31/50, Loss: 1.0638
# Epoch 32/50, Loss: 1.0816
# Epoch 33/50, Loss: 1.2051
# Epoch 34/50, Loss: 1.0481
# Epoch 35/50, Loss: 1.0156
# Epoch 36/50, Loss: 1.1886
# Epoch 37/50, Loss: 1.1432
# Epoch 38/50, Loss: 1.1680
# Epoch 39/50, Loss: 1.3003
# Epoch 40/50, Loss: 1.1220
# Epoch 41/50, Loss: 1.3633
# Epoch 42/50, Loss: 1.2177
# Epoch 43/50, Loss: 1.2626
# Epoch 44/50, Loss: 1.1912
# Epoch 45/50, Loss: 1.1647
# Epoch 46/50, Loss: 1.0458
# Epoch 47/50, Loss: 1.2774
# Epoch 48/50, Loss: 0.9971
# Epoch 49/50, Loss: 1.0423
# Epoch 50/50, Loss: 1.1006
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9133, F1 Class 0: 0.8764, F1 Class 1: 0.9333
#
# --- Training with train:test = 50:50 ---
# Epoch 1/50, Loss: 2.3073
# Epoch 2/50, Loss: 2.2007
# Epoch 3/50, Loss: 1.9862
# Epoch 4/50, Loss: 1.9226
# Epoch 5/50, Loss: 2.0359
# Epoch 6/50, Loss: 1.9535
# Epoch 7/50, Loss: 1.7257
# Epoch 8/50, Loss: 1.9313
# Epoch 9/50, Loss: 1.9513
# Epoch 10/50, Loss: 1.6472
# Epoch 11/50, Loss: 1.8162
# Epoch 12/50, Loss: 1.8769
# Epoch 13/50, Loss: 1.8541
# Epoch 14/50, Loss: 1.6362
# Epoch 15/50, Loss: 1.6757
# Epoch 16/50, Loss: 1.7750
# Epoch 17/50, Loss: 1.7416
# Epoch 18/50, Loss: 1.6945
# Epoch 19/50, Loss: 1.6229
# Epoch 20/50, Loss: 1.8190
# Epoch 21/50, Loss: 1.6547
# Epoch 22/50, Loss: 1.6975
# Epoch 23/50, Loss: 1.7680
# Epoch 24/50, Loss: 1.8256
# Epoch 25/50, Loss: 1.5757
# Epoch 26/50, Loss: 1.7144
# Epoch 27/50, Loss: 1.6485
# Epoch 28/50, Loss: 1.6025
# Epoch 29/50, Loss: 1.6113
# Epoch 30/50, Loss: 1.4795
# Epoch 31/50, Loss: 1.6391
# Epoch 32/50, Loss: 1.6643
# Epoch 33/50, Loss: 1.4791
# Epoch 34/50, Loss: 1.5739
# Epoch 35/50, Loss: 1.5608
# Epoch 36/50, Loss: 1.4723
# Epoch 37/50, Loss: 1.5411
# Epoch 38/50, Loss: 1.5838
# Epoch 39/50, Loss: 1.5697
# Epoch 40/50, Loss: 1.6464
# Epoch 41/50, Loss: 1.4489
# Epoch 42/50, Loss: 1.4800
# Epoch 43/50, Loss: 1.6072
# Epoch 44/50, Loss: 1.4910
# Epoch 45/50, Loss: 1.4298
# Epoch 46/50, Loss: 1.4188
# Epoch 47/50, Loss: 1.6981
# Epoch 48/50, Loss: 1.4189
# Epoch 49/50, Loss: 1.4283
# Epoch 50/50, Loss: 1.4228
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9152, F1 Class 0: 0.8792, F1 Class 1: 0.9347
#
# --- Training with train:test = 60:40 ---
# Epoch 1/50, Loss: 2.7256
# Epoch 2/50, Loss: 2.4639
# Epoch 3/50, Loss: 2.3566
# Epoch 4/50, Loss: 2.3859
# Epoch 5/50, Loss: 2.2161
# Epoch 6/50, Loss: 2.1565
# Epoch 7/50, Loss: 2.0183
# Epoch 8/50, Loss: 2.1109
# Epoch 9/50, Loss: 2.1367
# Epoch 10/50, Loss: 2.0987
# Epoch 11/50, Loss: 2.2153
# Epoch 12/50, Loss: 2.0455
# Epoch 13/50, Loss: 2.0170
# Epoch 14/50, Loss: 2.0497
# Epoch 15/50, Loss: 2.0034
# Epoch 16/50, Loss: 2.0714
# Epoch 17/50, Loss: 2.0396
# Epoch 18/50, Loss: 2.0465
# Epoch 19/50, Loss: 2.0887
# Epoch 20/50, Loss: 1.8814
# Epoch 21/50, Loss: 2.0311
# Epoch 22/50, Loss: 1.8448
# Epoch 23/50, Loss: 2.0130
# Epoch 24/50, Loss: 1.9185
# Epoch 25/50, Loss: 1.9259
# Epoch 26/50, Loss: 1.8777
# Epoch 27/50, Loss: 1.8520
# Epoch 28/50, Loss: 1.9390
# Epoch 29/50, Loss: 1.8626
# Epoch 30/50, Loss: 1.8979
# Epoch 31/50, Loss: 1.7146
# Epoch 32/50, Loss: 1.9240
# Epoch 33/50, Loss: 1.7846
# Epoch 34/50, Loss: 1.9014
# Epoch 35/50, Loss: 1.8176
# Epoch 36/50, Loss: 1.8800
# Epoch 37/50, Loss: 1.7566
# Epoch 38/50, Loss: 1.8563
# Epoch 39/50, Loss: 1.8623
# Epoch 40/50, Loss: 1.6754
# Epoch 41/50, Loss: 1.8229
# Epoch 42/50, Loss: 1.7182
# Epoch 43/50, Loss: 1.8038
# Epoch 44/50, Loss: 1.8134
# Epoch 45/50, Loss: 1.7608
# Epoch 46/50, Loss: 1.8034
# Epoch 47/50, Loss: 1.7169
# Epoch 48/50, Loss: 1.9206
# Epoch 49/50, Loss: 1.7630
# Epoch 50/50, Loss: 1.7281
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9147, F1 Class 0: 0.8782, F1 Class 1: 0.9343
#
# --- Training with train:test = 70:30 ---
# Epoch 1/50, Loss: 1.5813
# Epoch 2/50, Loss: 1.4962
# Epoch 3/50, Loss: 1.2166
# Epoch 4/50, Loss: 1.2965
# Epoch 5/50, Loss: 1.3771
# Epoch 6/50, Loss: 1.2373
# Epoch 7/50, Loss: 1.3742
# Epoch 8/50, Loss: 1.2106
# Epoch 9/50, Loss: 1.2919
# Epoch 10/50, Loss: 1.1524
# Epoch 11/50, Loss: 1.2479
# Epoch 12/50, Loss: 1.2786
# Epoch 13/50, Loss: 1.1048
# Epoch 14/50, Loss: 1.1878
# Epoch 15/50, Loss: 1.2459
# Epoch 16/50, Loss: 1.2837
# Epoch 17/50, Loss: 1.0091
# Epoch 18/50, Loss: 1.0732
# Epoch 19/50, Loss: 1.0470
# Epoch 20/50, Loss: 1.0931
# Epoch 21/50, Loss: 0.9374
# Epoch 22/50, Loss: 1.1358
# Epoch 23/50, Loss: 0.8573
# Epoch 24/50, Loss: 1.3035
# Epoch 25/50, Loss: 1.0901
# Epoch 26/50, Loss: 1.1641
# Epoch 27/50, Loss: 0.8774
# Epoch 28/50, Loss: 0.8499
# Epoch 29/50, Loss: 1.2142
# Epoch 30/50, Loss: 1.0750
# Epoch 31/50, Loss: 1.0604
# Epoch 32/50, Loss: 1.1109
# Epoch 33/50, Loss: 0.9568
# Epoch 34/50, Loss: 1.1291
# Epoch 35/50, Loss: 0.9892
# Epoch 36/50, Loss: 0.9111
# Epoch 37/50, Loss: 0.9777
# Epoch 38/50, Loss: 1.0238
# Epoch 39/50, Loss: 1.3208
# Epoch 40/50, Loss: 1.0594
# Epoch 41/50, Loss: 1.1536
# Epoch 42/50, Loss: 0.7155
# Epoch 43/50, Loss: 1.0207
# Epoch 44/50, Loss: 0.8401
# Epoch 45/50, Loss: 0.9576
# Epoch 46/50, Loss: 1.1290
# Epoch 47/50, Loss: 0.9021
# Epoch 48/50, Loss: 0.9119
# Epoch 49/50, Loss: 0.9686
# Epoch 50/50, Loss: 0.9396
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9155, F1 Class 0: 0.8798, F1 Class 1: 0.9348
#
# --- Training with train:test = 80:20 ---
# Epoch 1/50, Loss: 2.2226
# Epoch 2/50, Loss: 1.9511
# Epoch 3/50, Loss: 1.9729
# Epoch 4/50, Loss: 1.8311
# Epoch 5/50, Loss: 1.9170
# Epoch 6/50, Loss: 1.7760
# Epoch 7/50, Loss: 1.8127
# Epoch 8/50, Loss: 1.7817
# Epoch 9/50, Loss: 1.7299
# Epoch 10/50, Loss: 1.8181
# Epoch 11/50, Loss: 1.6342
# Epoch 12/50, Loss: 1.7624
# Epoch 13/50, Loss: 1.6058
# Epoch 14/50, Loss: 1.6334
# Epoch 15/50, Loss: 1.7619
# Epoch 16/50, Loss: 1.5464
# Epoch 17/50, Loss: 1.5671
# Epoch 18/50, Loss: 1.5267
# Epoch 19/50, Loss: 1.5327
# Epoch 20/50, Loss: 1.5327
# Epoch 21/50, Loss: 1.4703
# Epoch 22/50, Loss: 1.6738
# Epoch 23/50, Loss: 1.5843
# Epoch 24/50, Loss: 1.4314
# Epoch 25/50, Loss: 1.5975
# Epoch 26/50, Loss: 1.4900
# Epoch 27/50, Loss: 1.5355
# Epoch 28/50, Loss: 1.5310
# Epoch 29/50, Loss: 1.5857
# Epoch 30/50, Loss: 1.3762
# Epoch 31/50, Loss: 1.6017
# Epoch 32/50, Loss: 1.4526
# Epoch 33/50, Loss: 1.5567
# Epoch 34/50, Loss: 1.3707
# Epoch 35/50, Loss: 1.3787
# Epoch 36/50, Loss: 1.4702
# Epoch 37/50, Loss: 1.3773
# Epoch 38/50, Loss: 1.5350
# Epoch 39/50, Loss: 1.4969
# Epoch 40/50, Loss: 1.3699
# Epoch 41/50, Loss: 1.6086
# Epoch 42/50, Loss: 1.3967
# Epoch 43/50, Loss: 1.2704
# Epoch 44/50, Loss: 1.4075
# Epoch 45/50, Loss: 1.2521
# Epoch 46/50, Loss: 1.4065
# Epoch 47/50, Loss: 1.4531
# Epoch 48/50, Loss: 1.2676
# Epoch 49/50, Loss: 1.3563
# Epoch 50/50, Loss: 1.3497
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9176, F1 Class 0: 0.8828, F1 Class 1: 0.9364
#
# --- Training with train:test = 90:10 ---
# Epoch 1/50, Loss: 2.4881
# Epoch 2/50, Loss: 2.3346
# Epoch 3/50, Loss: 2.0935
# Epoch 4/50, Loss: 2.1717
# Epoch 5/50, Loss: 2.1986
# Epoch 6/50, Loss: 2.0209
# Epoch 7/50, Loss: 1.9720
# Epoch 8/50, Loss: 2.0283
# Epoch 9/50, Loss: 2.0398
# Epoch 10/50, Loss: 2.0033
# Epoch 11/50, Loss: 2.0145
# Epoch 12/50, Loss: 1.9568
# Epoch 13/50, Loss: 1.8639
# Epoch 14/50, Loss: 2.0067
# Epoch 15/50, Loss: 1.9584
# Epoch 16/50, Loss: 1.8787
# Epoch 17/50, Loss: 1.7998
# Epoch 18/50, Loss: 1.8309
# Epoch 19/50, Loss: 1.7796
# Epoch 20/50, Loss: 1.7671
# Epoch 21/50, Loss: 1.7854
# Epoch 22/50, Loss: 1.8361
# Epoch 23/50, Loss: 1.7740
# Epoch 24/50, Loss: 1.8006
# Epoch 25/50, Loss: 1.7798
# Epoch 26/50, Loss: 1.6985
# Epoch 27/50, Loss: 1.8224
# Epoch 28/50, Loss: 1.7380
# Epoch 29/50, Loss: 1.7886
# Epoch 30/50, Loss: 1.6636
# Epoch 31/50, Loss: 1.6580
# Epoch 32/50, Loss: 1.7419
# Epoch 33/50, Loss: 1.7442
# Epoch 34/50, Loss: 1.8036
# Epoch 35/50, Loss: 1.6147
# Epoch 36/50, Loss: 1.6943
# Epoch 37/50, Loss: 1.6507
# Epoch 38/50, Loss: 1.6247
# Epoch 39/50, Loss: 1.7608
# Epoch 40/50, Loss: 1.6840
# Epoch 41/50, Loss: 1.7010
# Epoch 42/50, Loss: 1.6164
# Epoch 43/50, Loss: 1.6231
# Epoch 44/50, Loss: 1.5504
# Epoch 45/50, Loss: 1.7028
# Epoch 46/50, Loss: 1.5970
# Epoch 47/50, Loss: 1.5920
# Epoch 48/50, Loss: 1.6144
# Epoch 49/50, Loss: 1.5306
# Epoch 50/50, Loss: 1.5336
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9173, F1 Class 0: 0.8826, F1 Class 1: 0.9362

# %%
def save_results(output_dir, ratio, encoder, rf, X_train_ssl, X_test_ssl, y_train, y_test, report):
    """Centralized function to save all results"""
    train_pct, test_pct = ratio
    
    # Save models
    encoder.save(f"{output_dir}/models/encoder_{train_pct}_{test_pct}.h5")
    joblib.dump(rf, f"{output_dir}/models/rf_{train_pct}_{test_pct}.joblib")
    
    # Save embeddings
    np.savez(f"{output_dir}/embeddings/embeddings_{train_pct}_{test_pct}.npz",
             X_train=X_train_ssl, X_test=X_test_ssl,
             y_train=y_train, y_test=y_test)
    
    # Save metrics
    result = {
        'train_pct': train_pct,
        'test_pct': test_pct,
        'accuracy': report['accuracy'],
        'precision_0': report['0']['precision'],
        'recall_0': report['0']['recall'],
        'f1_0': report['0']['f1-score'],
        'precision_1': report['1']['precision'],
        'recall_1': report['1']['recall'],
        'f1_1': report['1']['f1-score'],
        'timestamp': timestamp
    }
    
    with open(f"{output_dir}/metrics/result_{train_pct}_{test_pct}.json", 'w') as f:
        json.dump(result, f, indent=4)
    
    return result

# %% [markdown]
# MoCo

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
def build_encoder(input_dim):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)
    return models.Model(inputs, projection)

def contrastive_loss(query, key, queue, temperature=0.07):
    query = tf.math.l2_normalize(query, axis=1)
    key = tf.math.l2_normalize(key, axis=1)
    queue = tf.math.l2_normalize(queue, axis=1)

    l_pos = tf.reshape(tf.reduce_sum(query * key, axis=1), [-1,1])  # Nx1
    l_neg = tf.matmul(query, queue, transpose_b=True)              # NxK

    logits = tf.concat([l_pos, l_neg], axis=1) / temperature
    labels = tf.zeros(logits.shape[0], dtype=tf.int32)  # positives are first index

    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, logits)
    return tf.reduce_mean(loss)

def augment_batch(X):
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

# %%
input_dim = X_train.shape[1]  # your input feature dimension

query_encoder = build_encoder(input_dim)
key_encoder = build_encoder(input_dim)

# Initialize key encoder weights = query encoder weights
for q_var, k_var in zip(query_encoder.variables, key_encoder.variables):
    k_var.assign(q_var)

embedding_dim = 64
queue_size = 65536
queue = tf.Variable(tf.random.normal([queue_size, embedding_dim]), trainable=False)
queue.assign(tf.math.l2_normalize(queue, axis=1))
queue_ptr = tf.Variable(0, trainable=False, dtype=tf.int32)

@tf.function
def dequeue_and_enqueue(new_keys):
    batch_size = tf.shape(new_keys)[0]
    ptr = queue_ptr.value()
    update_indices = tf.range(ptr, ptr + batch_size) % queue_size
    queue.scatter_nd_update(tf.expand_dims(update_indices, 1), new_keys)
    queue_ptr.assign((ptr + batch_size) % queue_size)

@tf.function
def momentum_update(query_encoder, key_encoder, m=0.999):
    for q_var, k_var in zip(query_encoder.trainable_variables, key_encoder.trainable_variables):
        k_var.assign(m * k_var + (1 - m) * q_var)

# %%
optimizer = tf.keras.optimizers.Adam(3e-4)
batch_size = 512
epochs = 50
num_samples = X_train.shape[0]

results = []

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")
    num_samples = X_train.shape[0]
    idx = np.random.permutation(num_samples)
    X_shuffled = X_train[idx]

    for i in range(0, num_samples, batch_size):
        batch = X_shuffled[i:i+batch_size]
        if batch.shape[0] < 2:
            continue

        x_q = augment_batch(batch)
        x_k = augment_batch(batch)

        with tf.GradientTape() as tape:
            z_q = query_encoder(x_q, training=True)
            z_k = key_encoder(x_k, training=True)
            loss = contrastive_loss(z_q, z_k, queue)

        grads = tape.gradient(loss, query_encoder.trainable_variables)
        optimizer.apply_gradients(zip(grads, query_encoder.trainable_variables))

        momentum_update(query_encoder, key_encoder)
        dequeue_and_enqueue(tf.stop_gradient(z_k))

    print(f"Loss: {loss.numpy():.4f}")

    # Evaluate downstream classifier after each epoch
    X_train_ssl = query_encoder.predict(X_train)
    X_test_ssl = query_encoder.predict(X_test)

    rf = RandomForestClassifier(n_estimators=100, random_state=42)
    rf.fit(X_train_ssl, y_train)
    y_pred = rf.predict(X_test_ssl)
    report = classification_report(y_test, y_pred, output_dict=True)

    results.append({
        'epoch': epoch + 1,
        'loss': float(loss.numpy()),
        'accuracy': report['accuracy'],
        'f1_class_0': report['0']['f1-score'],
        'f1_class_1': report['1']['f1-score']
    })

# Optional: Convert results to DataFrame and display
import pandas as pd
results_df = pd.DataFrame(results)
print(results_df)
# Out:
# Epoch 1/50
# Loss: 7.3569
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 2/50
# Loss: 7.0952
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 3/50
# Loss: 7.0580
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 4/50
# Loss: 6.8807
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 5/50
# Loss: 6.6308
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 6/50
# Loss: 6.7789
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 7/50
# Loss: 6.7728
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 8/50
# Loss: 6.6008
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 9/50
# Loss: 6.5959
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 10/50
# Loss: 6.3849
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Epoch 11/50
# Loss: 6.5554
# 4356/6442 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
# Plot Loss vs Epoch
plt.figure(figsize=(10, 5))
plt.plot(results_df['epoch'], results_df['loss'], marker='o', label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Contrastive Loss')
plt.title('Training Loss per Epoch')
plt.grid(True)
plt.legend()
plt.show()

# Plot Accuracy vs Epoch
plt.figure(figsize=(10, 5))
plt.plot(results_df['epoch'], results_df['accuracy'], marker='o', color='green', label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Downstream Classifier Accuracy per Epoch')
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# -------- Step 1: Load & preprocess dataset --------
train = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.parquet")
test = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.parquet")
df = pd.concat([train, test])
df = df.drop(columns=['id', 'attack_cat'], errors='ignore')

cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    df[col] = pd.factorize(df[col])[0]

X = df.drop('label', axis=1)
y = df['label']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)

# -------- Step 2: Define MoCo components --------
def build_encoder(input_dim):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)
    return models.Model(inputs, projection)

def contrastive_loss(query, key, queue, temperature=0.07):
    query = tf.math.l2_normalize(query, axis=1)
    key = tf.math.l2_normalize(key, axis=1)
    queue = tf.math.l2_normalize(queue, axis=1)

    l_pos = tf.reshape(tf.reduce_sum(query * key, axis=1), [-1,1])  # Nx1
    l_neg = tf.matmul(query, queue, transpose_b=True)              # NxK

    logits = tf.concat([l_pos, l_neg], axis=1) / temperature
    labels = tf.zeros(logits.shape[0], dtype=tf.int32)  # positives are first

    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, logits)
    return tf.reduce_mean(loss)

def augment_batch(X):
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

embedding_dim = 64
queue_size = 65536

queue = tf.Variable(tf.random.normal([queue_size, embedding_dim]), trainable=False)
queue.assign(tf.math.l2_normalize(queue, axis=1))
queue_ptr = tf.Variable(0, trainable=False, dtype=tf.int32)

@tf.function
def dequeue_and_enqueue(new_keys):
    batch_size = tf.shape(new_keys)[0]
    ptr = queue_ptr.value()
    update_indices = tf.range(ptr, ptr + batch_size) % queue_size
    queue.scatter_nd_update(tf.expand_dims(update_indices, 1), new_keys)
    queue_ptr.assign((ptr + batch_size) % queue_size)

@tf.function
def momentum_update(query_encoder, key_encoder, m=0.999):
    for q_var, k_var in zip(query_encoder.trainable_variables, key_encoder.trainable_variables):
        k_var.assign(m * k_var + (1 - m) * q_var)

# -------- Step 3: Train and evaluate across train:test splits --------
ratios = [(10,90), (20,80), (30,70), (40,60), (50,50), (60,40), (70,30), (80,20), (90,10)]

all_results = []

for train_pct, test_pct in ratios:
    print(f"\n--- Train:Test = {train_pct}:{test_pct} ---")

    # Split dataset accordingly
    X_train, X_test, y_train, y_test = train_test_split(
        X.values.astype(np.float32), y.values,
        test_size=test_pct/100,
        stratify=y,
        random_state=42
    )

    # Initialize encoders and optimizer
    query_encoder = build_encoder(X_train.shape[1])
    key_encoder = build_encoder(X_train.shape[1])
    for q_var, k_var in zip(query_encoder.variables, key_encoder.variables):
        k_var.assign(q_var)

    optimizer = tf.keras.optimizers.Adam(3e-4)
    batch_size = 512
    epochs = 20
    num_samples = X_train.shape[0]

    for epoch in range(epochs):
        idx = np.random.permutation(num_samples)
        X_shuffled = X_train[idx]

        for i in range(0, num_samples, batch_size):
            batch = X_shuffled[i:i+batch_size]
            if batch.shape[0] < 2:
                continue

            x_q = augment_batch(batch)
            x_k = augment_batch(batch)

            with tf.GradientTape() as tape:
                z_q = query_encoder(x_q, training=True)
                z_k = key_encoder(x_k, training=True)
                loss = contrastive_loss(z_q, z_k, queue)

            grads = tape.gradient(loss, query_encoder.trainable_variables)
            optimizer.apply_gradients(zip(grads, query_encoder.trainable_variables))

            momentum_update(query_encoder, key_encoder)
            dequeue_and_enqueue(tf.stop_gradient(z_k))

        print(f"Epoch {epoch+1}/{epochs}, Loss: {loss.numpy():.4f}")

        # Evaluate downstream classifier
        X_train_ssl = query_encoder.predict(X_train)
        X_test_ssl = query_encoder.predict(X_test)

        rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
        rf.fit(X_train_ssl, y_train)
        y_pred = rf.predict(X_test_ssl)
        report = classification_report(y_test, y_pred, output_dict=True)

        acc = report['accuracy']
        f1_0 = report['0']['f1-score']
        f1_1 = report['1']['f1-score']

        all_results.append({
            'train_pct': train_pct,
            'test_pct': test_pct,
            'epoch': epoch + 1,
            'loss': float(loss.numpy()),
            'accuracy': acc,
            'f1_class_0': f1_0,
            'f1_class_1': f1_1
        })

        print(f"Accuracy: {acc:.4f}, F1 Class 0: {f1_0:.4f}, F1 Class 1: {f1_1:.4f}")

# -------- Step 4: Save results --------
results_df = pd.DataFrame(all_results)
results_df.to_csv('moco_ssl_rf_results_all_epochs.csv', index=False)
print("\nSaved results to 'moco_ssl_rf_results_all_epochs.csv'")

# -------- Step 5: Visualization --------
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
ratios_unique = results_df[['train_pct', 'test_pct']].drop_duplicates()

# Accuracy vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['accuracy'], marker='o', label=label)
plt.title("Accuracy vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()

# Loss vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['loss'], marker='o', label=label)
plt.title("Contrastive Loss vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()
# Out:
# 2025-05-17 09:12:01.984998: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747473122.193409      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747473122.251531      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# I0000 00:00:1747473136.223520      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1747473136.224144      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# --- Train:Test = 10:90 ---
# Epoch 1/20, Loss: 7.3590
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747473143.118056     104 service.cc:148] XLA service 0x7bda71a8d4d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747473143.118750     104 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1747473143.118770     104 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1747473143.199359     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 134/806 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# I0000 00:00:1747473143.425293     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9021, F1 Class 0: 0.8591, F1 Class 1: 0.9249
# Epoch 2/20, Loss: 7.8337
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9033, F1 Class 0: 0.8609, F1 Class 1: 0.9259
# Epoch 3/20, Loss: 7.8626
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9034, F1 Class 0: 0.8610, F1 Class 1: 0.9259
# Epoch 4/20, Loss: 7.5650
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9040, F1 Class 0: 0.8623, F1 Class 1: 0.9263
# Epoch 5/20, Loss: 7.4304
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9037, F1 Class 0: 0.8615, F1 Class 1: 0.9262
# Epoch 6/20, Loss: 7.3442
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9035, F1 Class 0: 0.8612, F1 Class 1: 0.9261
# Epoch 7/20, Loss: 7.4399
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9040, F1 Class 0: 0.8620, F1 Class 1: 0.9264
# Epoch 8/20, Loss: 7.2453
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9042, F1 Class 0: 0.8622, F1 Class 1: 0.9265
# Epoch 9/20, Loss: 7.3585
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9044, F1 Class 0: 0.8623, F1 Class 1: 0.9267
# Epoch 10/20, Loss: 7.1055
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9050, F1 Class 0: 0.8631, F1 Class 1: 0.9272
# Epoch 11/20, Loss: 7.5015
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9048, F1 Class 0: 0.8627, F1 Class 1: 0.9271
# Epoch 12/20, Loss: 7.3153
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9055, F1 Class 0: 0.8639, F1 Class 1: 0.9276
# Epoch 13/20, Loss: 7.1962
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9060, F1 Class 0: 0.8647, F1 Class 1: 0.9279
# Epoch 14/20, Loss: 7.4583
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8639, F1 Class 1: 0.9276
# Epoch 15/20, Loss: 7.4645
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9056, F1 Class 0: 0.8642, F1 Class 1: 0.9277
# Epoch 16/20, Loss: 7.3922
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9062, F1 Class 0: 0.8651, F1 Class 1: 0.9281
# Epoch 17/20, Loss: 7.4013
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9065, F1 Class 0: 0.8658, F1 Class 1: 0.9283
# Epoch 18/20, Loss: 7.2567
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9061, F1 Class 0: 0.8649, F1 Class 1: 0.9280
# Epoch 19/20, Loss: 7.3933
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9066, F1 Class 0: 0.8659, F1 Class 1: 0.9284
# Epoch 20/20, Loss: 7.0424
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9065, F1 Class 0: 0.8656, F1 Class 1: 0.9283
#
# --- Train:Test = 20:80 ---
# Epoch 1/20, Loss: 7.5983
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9068, F1 Class 0: 0.8666, F1 Class 1: 0.9284
# Epoch 2/20, Loss: 7.4598
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9077, F1 Class 0: 0.8679, F1 Class 1: 0.9291
# Epoch 3/20, Loss: 7.3663
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8678, F1 Class 1: 0.9290
# Epoch 4/20, Loss: 7.2613
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9088, F1 Class 0: 0.8696, F1 Class 1: 0.9299
# Epoch 5/20, Loss: 7.3521
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9087, F1 Class 0: 0.8693, F1 Class 1: 0.9298
# Epoch 6/20, Loss: 7.2613
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9088, F1 Class 0: 0.8698, F1 Class 1: 0.9299
# Epoch 7/20, Loss: 7.0954
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9100, F1 Class 0: 0.8716, F1 Class 1: 0.9308
# Epoch 8/20, Loss: 7.0010
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9101, F1 Class 0: 0.8717, F1 Class 1: 0.9309
# Epoch 9/20, Loss: 7.1682
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9101, F1 Class 0: 0.8717, F1 Class 1: 0.9308
# Epoch 10/20, Loss: 7.0414
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9109, F1 Class 0: 0.8731, F1 Class 1: 0.9314
# Epoch 11/20, Loss: 7.0915
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9106, F1 Class 0: 0.8725, F1 Class 1: 0.9311
# Epoch 12/20, Loss: 7.0835
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9111, F1 Class 0: 0.8733, F1 Class 1: 0.9315
# Epoch 13/20, Loss: 7.0086
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9114, F1 Class 0: 0.8738, F1 Class 1: 0.9317
# Epoch 14/20, Loss: 7.0570
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9111, F1 Class 0: 0.8735, F1 Class 1: 0.9314
# Epoch 15/20, Loss: 6.9977
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8743, F1 Class 1: 0.9320
# Epoch 16/20, Loss: 7.0809
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9112, F1 Class 0: 0.8737, F1 Class 1: 0.9316
# Epoch 17/20, Loss: 6.8878
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8745, F1 Class 1: 0.9320
# Epoch 18/20, Loss: 6.8162
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9119, F1 Class 0: 0.8748, F1 Class 1: 0.9321
# Epoch 19/20, Loss: 6.9051
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9121, F1 Class 0: 0.8750, F1 Class 1: 0.9323
# Epoch 20/20, Loss: 6.6958
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9117, F1 Class 0: 0.8743, F1 Class 1: 0.9319
#
# --- Train:Test = 30:70 ---
# Epoch 1/20, Loss: 7.5544
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9087, F1 Class 0: 0.8693, F1 Class 1: 0.9298
# Epoch 2/20, Loss: 7.3115
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9099, F1 Class 0: 0.8712, F1 Class 1: 0.9307
# Epoch 3/20, Loss: 7.3517
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9116, F1 Class 0: 0.8738, F1 Class 1: 0.9320
# Epoch 4/20, Loss: 7.3799
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9113, F1 Class 0: 0.8733, F1 Class 1: 0.9318
# Epoch 5/20, Loss: 7.2079
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8740, F1 Class 1: 0.9322
# Epoch 6/20, Loss: 7.2089
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9125, F1 Class 0: 0.8753, F1 Class 1: 0.9327
# Epoch 7/20, Loss: 7.0684
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9127, F1 Class 0: 0.8754, F1 Class 1: 0.9329
# Epoch 8/20, Loss: 7.0345
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9131, F1 Class 0: 0.8760, F1 Class 1: 0.9331
# Epoch 9/20, Loss: 7.1023
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9134, F1 Class 0: 0.8764, F1 Class 1: 0.9333
# Epoch 10/20, Loss: 7.0647
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9138, F1 Class 0: 0.8772, F1 Class 1: 0.9336
# Epoch 11/20, Loss: 7.0400
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9141, F1 Class 0: 0.8777, F1 Class 1: 0.9338
# Epoch 12/20, Loss: 6.9769
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9136, F1 Class 0: 0.8770, F1 Class 1: 0.9334
# Epoch 13/20, Loss: 6.9487
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9138, F1 Class 0: 0.8774, F1 Class 1: 0.9335
# Epoch 14/20, Loss: 7.0105
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9140, F1 Class 0: 0.8777, F1 Class 1: 0.9337
# Epoch 15/20, Loss: 6.9802
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9137, F1 Class 0: 0.8773, F1 Class 1: 0.9335
# Epoch 16/20, Loss: 6.8230
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9137, F1 Class 0: 0.8771, F1 Class 1: 0.9335
# Epoch 17/20, Loss: 6.9724
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9139, F1 Class 0: 0.8776, F1 Class 1: 0.9336
# Epoch 18/20, Loss: 6.7752
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9138, F1 Class 0: 0.8773, F1 Class 1: 0.9335
# Epoch 19/20, Loss: 6.7755
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9139, F1 Class 0: 0.8777, F1 Class 1: 0.9336
# Epoch 20/20, Loss: 6.7118
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9136, F1 Class 0: 0.8770, F1 Class 1: 0.9334
#
# --- Train:Test = 40:60 ---
# Epoch 1/20, Loss: 7.6499
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9115, F1 Class 0: 0.8742, F1 Class 1: 0.9317
# Epoch 2/20, Loss: 7.3682
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9137, F1 Class 0: 0.8774, F1 Class 1: 0.9334
# Epoch 3/20, Loss: 7.5720
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9138, F1 Class 0: 0.8776, F1 Class 1: 0.9334
# Epoch 4/20, Loss: 7.4406
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9149, F1 Class 0: 0.8793, F1 Class 1: 0.9342
# Epoch 5/20, Loss: 7.1058
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9157, F1 Class 0: 0.8803, F1 Class 1: 0.9349
# Epoch 6/20, Loss: 7.0246
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9158, F1 Class 0: 0.8807, F1 Class 1: 0.9349
# Epoch 7/20, Loss: 7.0850
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9160, F1 Class 0: 0.8811, F1 Class 1: 0.9350
# Epoch 8/20, Loss: 6.9852
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9165, F1 Class 0: 0.8819, F1 Class 1: 0.9354
# Epoch 9/20, Loss: 6.7975
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9163, F1 Class 0: 0.8816, F1 Class 1: 0.9353
# Epoch 10/20, Loss: 7.0729
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9161, F1 Class 0: 0.8812, F1 Class 1: 0.9351
# Epoch 11/20, Loss: 7.0239
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9165, F1 Class 0: 0.8818, F1 Class 1: 0.9354
# Epoch 12/20, Loss: 6.6972
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9167, F1 Class 0: 0.8822, F1 Class 1: 0.9356
# Epoch 13/20, Loss: 6.7105
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9157, F1 Class 0: 0.8808, F1 Class 1: 0.9348
# Epoch 14/20, Loss: 6.7864
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9156, F1 Class 0: 0.8805, F1 Class 1: 0.9348
# Epoch 15/20, Loss: 6.3779
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9166, F1 Class 0: 0.8820, F1 Class 1: 0.9355
# Epoch 16/20, Loss: 6.6028
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9159, F1 Class 0: 0.8808, F1 Class 1: 0.9350
# Epoch 17/20, Loss: 6.6356
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9155, F1 Class 0: 0.8801, F1 Class 1: 0.9347
# Epoch 18/20, Loss: 6.6150
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9153, F1 Class 0: 0.8798, F1 Class 1: 0.9345
# Epoch 19/20, Loss: 6.5005
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9154, F1 Class 0: 0.8799, F1 Class 1: 0.9347
# Epoch 20/20, Loss: 6.3820
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9149, F1 Class 0: 0.8792, F1 Class 1: 0.9343
#
# --- Train:Test = 50:50 ---
# Epoch 1/20, Loss: 7.3957
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9153, F1 Class 0: 0.8799, F1 Class 1: 0.9346
# Epoch 2/20, Loss: 7.3354
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9166, F1 Class 0: 0.8818, F1 Class 1: 0.9356
# Epoch 3/20, Loss: 7.1764
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9169, F1 Class 0: 0.8820, F1 Class 1: 0.9359
# Epoch 4/20, Loss: 7.1968
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9175, F1 Class 0: 0.8830, F1 Class 1: 0.9363
# Epoch 5/20, Loss: 6.9535
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9179, F1 Class 0: 0.8835, F1 Class 1: 0.9366
# Epoch 6/20, Loss: 7.0603
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9181, F1 Class 0: 0.8840, F1 Class 1: 0.9368
# Epoch 7/20, Loss: 6.9780
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9181, F1 Class 0: 0.8839, F1 Class 1: 0.9367
# Epoch 8/20, Loss: 6.9253
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9185, F1 Class 0: 0.8844, F1 Class 1: 0.9370
# Epoch 9/20, Loss: 6.7536
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9169, F1 Class 0: 0.8823, F1 Class 1: 0.9358
# Epoch 10/20, Loss: 6.7998
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9167, F1 Class 0: 0.8819, F1 Class 1: 0.9357
# Epoch 11/20, Loss: 6.7984
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9171, F1 Class 0: 0.8825, F1 Class 1: 0.9360
# Epoch 12/20, Loss: 6.5078
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9167, F1 Class 0: 0.8817, F1 Class 1: 0.9357
# Epoch 13/20, Loss: 6.6918
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9162, F1 Class 0: 0.8809, F1 Class 1: 0.9353
# Epoch 14/20, Loss: 6.5649
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9163, F1 Class 0: 0.8811, F1 Class 1: 0.9354
# Epoch 15/20, Loss: 6.6871
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9172, F1 Class 0: 0.8824, F1 Class 1: 0.9361
# Epoch 16/20, Loss: 6.5450
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9171, F1 Class 0: 0.8823, F1 Class 1: 0.9360
# Epoch 17/20, Loss: 6.4907
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9175, F1 Class 0: 0.8828, F1 Class 1: 0.9363
# Epoch 18/20, Loss: 6.4564
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9164, F1 Class 0: 0.8813, F1 Class 1: 0.9355
# Epoch 19/20, Loss: 6.4398
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9166, F1 Class 0: 0.8816, F1 Class 1: 0.9357
# Epoch 20/20, Loss: 6.6776
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9164, F1 Class 0: 0.8814, F1 Class 1: 0.9355
#
# --- Train:Test = 60:40 ---
# Epoch 1/20, Loss: 7.5443
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9151, F1 Class 0: 0.8790, F1 Class 1: 0.9346
# Epoch 2/20, Loss: 7.2558
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9170, F1 Class 0: 0.8820, F1 Class 1: 0.9359
# Epoch 3/20, Loss: 7.1439
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9179, F1 Class 0: 0.8836, F1 Class 1: 0.9366
# Epoch 4/20, Loss: 7.1328
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9186, F1 Class 0: 0.8848, F1 Class 1: 0.9371
# Epoch 5/20, Loss: 6.9168
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9193, F1 Class 0: 0.8856, F1 Class 1: 0.9376
# Epoch 6/20, Loss: 6.9335
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9189, F1 Class 0: 0.8852, F1 Class 1: 0.9373
# Epoch 7/20, Loss: 6.8523
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9190, F1 Class 0: 0.8852, F1 Class 1: 0.9374
# Epoch 8/20, Loss: 6.7799
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9185, F1 Class 0: 0.8847, F1 Class 1: 0.9370
# Epoch 9/20, Loss: 6.6928
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9190, F1 Class 0: 0.8853, F1 Class 1: 0.9374
# Epoch 10/20, Loss: 6.6222
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9187, F1 Class 0: 0.8846, F1 Class 1: 0.9372
# Epoch 11/20, Loss: 6.5739
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9182, F1 Class 0: 0.8839, F1 Class 1: 0.9368
# Epoch 12/20, Loss: 6.6221
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9179, F1 Class 0: 0.8834, F1 Class 1: 0.9366
# Epoch 13/20, Loss: 6.5883
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9182, F1 Class 0: 0.8838, F1 Class 1: 0.9368
# Epoch 14/20, Loss: 6.4918
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9183, F1 Class 0: 0.8840, F1 Class 1: 0.9369
# Epoch 15/20, Loss: 6.5759
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9178, F1 Class 0: 0.8831, F1 Class 1: 0.9366
# Epoch 16/20, Loss: 6.5741
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9173, F1 Class 0: 0.8825, F1 Class 1: 0.9362
# Epoch 17/20, Loss: 6.3819
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9173, F1 Class 0: 0.8824, F1 Class 1: 0.9362
# Epoch 18/20, Loss: 6.5689
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9177, F1 Class 0: 0.8830, F1 Class 1: 0.9365
# Epoch 19/20, Loss: 6.2518
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9183, F1 Class 0: 0.8839, F1 Class 1: 0.9370
# Epoch 20/20, Loss: 6.3724
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9177, F1 Class 0: 0.8832, F1 Class 1: 0.9365
#
# --- Train:Test = 70:30 ---
# Epoch 1/20, Loss: 7.2792
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9169, F1 Class 0: 0.8824, F1 Class 1: 0.9358
# Epoch 2/20, Loss: 7.5267
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9176, F1 Class 0: 0.8835, F1 Class 1: 0.9363
# Epoch 3/20, Loss: 6.8993
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9188, F1 Class 0: 0.8852, F1 Class 1: 0.9372
# Epoch 4/20, Loss: 7.2258
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9186, F1 Class 0: 0.8850, F1 Class 1: 0.9370
# Epoch 5/20, Loss: 6.8669
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9192, F1 Class 0: 0.8860, F1 Class 1: 0.9374
# Epoch 6/20, Loss: 7.3394
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9199, F1 Class 0: 0.8870, F1 Class 1: 0.9380
# Epoch 7/20, Loss: 6.8432
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9188, F1 Class 0: 0.8853, F1 Class 1: 0.9372
# Epoch 8/20, Loss: 6.7157
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9190, F1 Class 0: 0.8858, F1 Class 1: 0.9373
# Epoch 9/20, Loss: 6.6414
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9189, F1 Class 0: 0.8855, F1 Class 1: 0.9372
# Epoch 10/20, Loss: 6.4716
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9196, F1 Class 0: 0.8864, F1 Class 1: 0.9378
# Epoch 11/20, Loss: 6.4440
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9187, F1 Class 0: 0.8850, F1 Class 1: 0.9371
# Epoch 12/20, Loss: 6.4304
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9186, F1 Class 0: 0.8850, F1 Class 1: 0.9370
# Epoch 13/20, Loss: 6.5940
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9189, F1 Class 0: 0.8854, F1 Class 1: 0.9372
# Epoch 14/20, Loss: 6.6705
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9188, F1 Class 0: 0.8851, F1 Class 1: 0.9372
# Epoch 15/20, Loss: 6.3932
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9197, F1 Class 0: 0.8867, F1 Class 1: 0.9379
# Epoch 16/20, Loss: 6.3998
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9190, F1 Class 0: 0.8856, F1 Class 1: 0.9373
# Epoch 17/20, Loss: 6.3109
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9190, F1 Class 0: 0.8855, F1 Class 1: 0.9373
# Epoch 18/20, Loss: 6.2570
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9189, F1 Class 0: 0.8853, F1 Class 1: 0.9373
# Epoch 19/20, Loss: 6.1948
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9193, F1 Class 0: 0.8859, F1 Class 1: 0.9376
# Epoch 20/20, Loss: 5.9419
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9186, F1 Class 0: 0.8850, F1 Class 1: 0.9371
#
# --- Train:Test = 80:20 ---
# Epoch 1/20, Loss: 7.2662
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9188, F1 Class 0: 0.8848, F1 Class 1: 0.9372
# Epoch 2/20, Loss: 7.2927
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9199, F1 Class 0: 0.8867, F1 Class 1: 0.9380
# Epoch 3/20, Loss: 7.1814
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9212, F1 Class 0: 0.8886, F1 Class 1: 0.9391
# Epoch 4/20, Loss: 6.8290
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9207, F1 Class 0: 0.8879, F1 Class 1: 0.9387
# Epoch 5/20, Loss: 6.8188
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9205, F1 Class 0: 0.8876, F1 Class 1: 0.9385
# Epoch 6/20, Loss: 6.7489
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9201, F1 Class 0: 0.8869, F1 Class 1: 0.9382
# Epoch 7/20, Loss: 6.5646
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9197, F1 Class 0: 0.8862, F1 Class 1: 0.9380
# Epoch 8/20, Loss: 6.7273
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9205, F1 Class 0: 0.8877, F1 Class 1: 0.9385
# Epoch 9/20, Loss: 6.4392
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9203, F1 Class 0: 0.8874, F1 Class 1: 0.9383
# Epoch 10/20, Loss: 6.5525
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9209, F1 Class 0: 0.8882, F1 Class 1: 0.9388
# Epoch 11/20, Loss: 6.4526
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9212, F1 Class 0: 0.8888, F1 Class 1: 0.9390
# Epoch 12/20, Loss: 6.3326
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9201, F1 Class 0: 0.8870, F1 Class 1: 0.9382
# Epoch 13/20, Loss: 6.3734
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9201, F1 Class 0: 0.8871, F1 Class 1: 0.9382
# Epoch 14/20, Loss: 6.4820
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9198, F1 Class 0: 0.8867, F1 Class 1: 0.9379
# Epoch 15/20, Loss: 6.3577
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9202, F1 Class 0: 0.8873, F1 Class 1: 0.9382
# Epoch 16/20, Loss: 6.2069
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9195, F1 Class 0: 0.8863, F1 Class 1: 0.9377
# Epoch 17/20, Loss: 6.3706
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9195, F1 Class 0: 0.8862, F1 Class 1: 0.9378
# Epoch 18/20, Loss: 6.0662
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9201, F1 Class 0: 0.8870, F1 Class 1: 0.9382
# Epoch 19/20, Loss: 6.2256
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9205, F1 Class 0: 0.8877, F1 Class 1: 0.9385
# Epoch 20/20, Loss: 6.5201
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9204, F1 Class 0: 0.8874, F1 Class 1: 0.9384
#
# --- Train:Test = 90:10 ---
# Epoch 1/20, Loss: 7.4170
# 2976/7248 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step

# %% [markdown]
# **BYOL (Bootstrap Your Own Latent)**

# %%
#1. Import Libraries and Prepare Data
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
train = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_training-set.parquet")
test = pd.read_parquet("/kaggle/input/unsw-nb15/UNSW_NB15_testing-set.parquet")
df = pd.concat([train, test])
df = df.drop(columns=['id', 'attack_cat'], errors='ignore')

# Preprocessing
cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    df[col] = pd.factorize(df[col])[0]

X = df.drop('label', axis=1)
y = df['label']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
#2. Define BYOL Model Components
def build_encoder(input_dim):
    """Defines the encoder network for BYOL."""
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)
    return models.Model(inputs, projection)

def momentum_update(query_encoder, target_encoder, m=0.99):
    """Momentum update of target encoder."""
    for q_var, t_var in zip(query_encoder.variables, target_encoder.variables):
        t_var.assign(m * t_var + (1 - m) * q_var)

def augment_batch(X):
    """Augmentation function to generate noisy inputs."""
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

# %%
#Define Training Loop and Downstream Classifier
ratios = [(10, 90), (20, 80), (30, 70), (40, 60), (50, 50), (60, 40), (70, 30), (80, 20), (90, 10)]

all_results = []

for train_pct, test_pct in ratios:
    print(f"\n--- Train:Test = {train_pct}:{test_pct} ---")

    # Split data according to the ratio
    X_train, X_test, y_train, y_test = train_test_split(
        X.values.astype(np.float32), y.values,
        test_size=test_pct / 100,
        stratify=y,
        random_state=42
    )

    # Initialize the encoders (online and target)
    query_encoder = build_encoder(X_train.shape[1])
    target_encoder = build_encoder(X_train.shape[1])
    
    # Initialize target encoder weights with online encoder weights (momentum update)
    for q_var, t_var in zip(query_encoder.variables, target_encoder.variables):
        t_var.assign(q_var)

    # Set up optimizer
    optimizer = tf.keras.optimizers.Adam(3e-4)
    batch_size = 512
    epochs = 20
    num_samples = X_train.shape[0]

    # Training loop for BYOL
    for epoch in range(epochs):
        idx = np.random.permutation(num_samples)
        X_shuffled = X_train[idx]

        for i in range(0, num_samples, batch_size):
            batch = X_shuffled[i:i + batch_size]
            if batch.shape[0] < 2:
                continue

            # Augmentation
            x_q = augment_batch(batch)  # Query augmentation
            x_k = augment_batch(batch)  # Key augmentation

            with tf.GradientTape() as tape:
                z_q = query_encoder(x_q, training=True)
                z_k = target_encoder(x_k, training=True)
                loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
                    labels=tf.zeros(z_q.shape[0], dtype=tf.int32),
                    logits=tf.matmul(tf.math.l2_normalize(z_q, axis=1), tf.math.l2_normalize(z_k, axis=1), transpose_b=True)
                ))

            grads = tape.gradient(loss, query_encoder.trainable_variables)
            optimizer.apply_gradients(zip(grads, query_encoder.trainable_variables))

            # Momentum update of target encoder
            momentum_update(query_encoder, target_encoder)

        print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss.numpy():.4f}")

        # Evaluate downstream classifier (RandomForest)
        X_train_ssl = query_encoder.predict(X_train)
        X_test_ssl = query_encoder.predict(X_test)

        rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
        rf.fit(X_train_ssl, y_train)
        y_pred = rf.predict(X_test_ssl)
        report = classification_report(y_test, y_pred, output_dict=True)

        acc = report['accuracy']
        f1_0 = report['0']['f1-score']
        f1_1 = report['1']['f1-score']

        all_results.append({
            'train_pct': train_pct,
            'test_pct': test_pct,
            'epoch': epoch + 1,
            'loss': float(loss.numpy()),
            'accuracy': acc,
            'f1_class_0': f1_0,
            'f1_class_1': f1_1
        })

        print(f"Accuracy: {acc:.4f}, F1 Class 0: {f1_0:.4f}, F1 Class 1: {f1_1:.4f}")
# Out:
# --- Train:Test = 10:90 ---
# Epoch 1/20, Loss: 0.0000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749840123.189471     111 service.cc:148] XLA service 0x7b6ff8004740 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749840123.190128     111 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749840123.190153     111 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1749840123.281461     111 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 111/806 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# I0000 00:00:1749840123.577374     111 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.9039, F1 Class 0: 0.8617, F1 Class 1: 0.9263
# Epoch 2/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.9015, F1 Class 0: 0.8580, F1 Class 1: 0.9246
# Epoch 3/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.9001, F1 Class 0: 0.8562, F1 Class 1: 0.9235
# Epoch 4/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8989, F1 Class 0: 0.8537, F1 Class 1: 0.9228
# Epoch 5/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8983, F1 Class 0: 0.8529, F1 Class 1: 0.9222
# Epoch 6/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8967, F1 Class 0: 0.8505, F1 Class 1: 0.9211
# Epoch 7/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8955, F1 Class 0: 0.8487, F1 Class 1: 0.9202
# Epoch 8/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8967, F1 Class 0: 0.8505, F1 Class 1: 0.9211
# Epoch 9/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8946, F1 Class 0: 0.8470, F1 Class 1: 0.9196
# Epoch 10/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8932, F1 Class 0: 0.8450, F1 Class 1: 0.9185
# Epoch 11/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8941, F1 Class 0: 0.8466, F1 Class 1: 0.9191
# Epoch 12/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8957, F1 Class 0: 0.8493, F1 Class 1: 0.9203
# Epoch 13/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8927, F1 Class 0: 0.8455, F1 Class 1: 0.9178
# Epoch 14/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8932, F1 Class 0: 0.8466, F1 Class 1: 0.9181
# Epoch 15/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8939, F1 Class 0: 0.8473, F1 Class 1: 0.9187
# Epoch 16/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8927, F1 Class 0: 0.8454, F1 Class 1: 0.9179
# Epoch 17/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8901, F1 Class 0: 0.8410, F1 Class 1: 0.9161
# Epoch 18/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8926, F1 Class 0: 0.8450, F1 Class 1: 0.9178
# Epoch 19/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8884, F1 Class 0: 0.8396, F1 Class 1: 0.9144
# Epoch 20/20, Loss: 0.0000
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# Accuracy: 0.8915, F1 Class 0: 0.8433, F1 Class 1: 0.9170
#
# --- Train:Test = 20:80 ---
# Epoch 1/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9051, F1 Class 0: 0.8643, F1 Class 1: 0.9270
# Epoch 2/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9023, F1 Class 0: 0.8599, F1 Class 1: 0.9250
# Epoch 3/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8996, F1 Class 0: 0.8559, F1 Class 1: 0.9230
# Epoch 4/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8989, F1 Class 0: 0.8541, F1 Class 1: 0.9226
# Epoch 5/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8975, F1 Class 0: 0.8521, F1 Class 1: 0.9216
# Epoch 6/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8961, F1 Class 0: 0.8506, F1 Class 1: 0.9204
# Epoch 7/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8954, F1 Class 0: 0.8494, F1 Class 1: 0.9198
# Epoch 8/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8944, F1 Class 0: 0.8474, F1 Class 1: 0.9192
# Epoch 9/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8929, F1 Class 0: 0.8457, F1 Class 1: 0.9180
# Epoch 10/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9003, F1 Class 0: 0.8583, F1 Class 1: 0.9231
# Epoch 11/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8927, F1 Class 0: 0.8472, F1 Class 1: 0.9174
# Epoch 12/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8845, F1 Class 0: 0.8346, F1 Class 1: 0.9112
# Epoch 13/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8893, F1 Class 0: 0.8419, F1 Class 1: 0.9148
# Epoch 14/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8896, F1 Class 0: 0.8419, F1 Class 1: 0.9152
# Epoch 15/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8811, F1 Class 0: 0.8309, F1 Class 1: 0.9083
# Epoch 16/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8885, F1 Class 0: 0.8401, F1 Class 1: 0.9145
# Epoch 17/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8867, F1 Class 0: 0.8378, F1 Class 1: 0.9129
# Epoch 18/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8778, F1 Class 0: 0.8265, F1 Class 1: 0.9057
# Epoch 19/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8844, F1 Class 0: 0.8348, F1 Class 1: 0.9111
# Epoch 20/20, Loss: 0.0000
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8811, F1 Class 0: 0.8303, F1 Class 1: 0.9085
#
# --- Train:Test = 30:70 ---
# Epoch 1/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8678, F1 Class 1: 0.9289
# Epoch 2/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9049, F1 Class 0: 0.8640, F1 Class 1: 0.9269
# Epoch 3/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9017, F1 Class 0: 0.8589, F1 Class 1: 0.9245
# Epoch 4/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8999, F1 Class 0: 0.8559, F1 Class 1: 0.9234
# Epoch 5/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8986, F1 Class 0: 0.8538, F1 Class 1: 0.9223
# Epoch 6/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8960, F1 Class 0: 0.8508, F1 Class 1: 0.9202
# Epoch 7/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8976, F1 Class 0: 0.8535, F1 Class 1: 0.9213
# Epoch 8/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8947, F1 Class 0: 0.8492, F1 Class 1: 0.9191
# Epoch 9/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8970, F1 Class 0: 0.8532, F1 Class 1: 0.9207
# Epoch 10/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8897, F1 Class 0: 0.8425, F1 Class 1: 0.9152
# Epoch 11/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8902, F1 Class 0: 0.8430, F1 Class 1: 0.9155
# Epoch 12/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8960, F1 Class 0: 0.8512, F1 Class 1: 0.9201
# Epoch 13/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8931, F1 Class 0: 0.8471, F1 Class 1: 0.9178
# Epoch 14/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8945, F1 Class 0: 0.8497, F1 Class 1: 0.9187
# Epoch 15/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8983, F1 Class 0: 0.8557, F1 Class 1: 0.9215
# Epoch 16/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8900, F1 Class 0: 0.8438, F1 Class 1: 0.9152
# Epoch 17/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8851, F1 Class 0: 0.8368, F1 Class 1: 0.9114
# Epoch 18/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8876, F1 Class 0: 0.8403, F1 Class 1: 0.9133
# Epoch 19/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8862, F1 Class 0: 0.8392, F1 Class 1: 0.9120
# Epoch 20/20, Loss: 0.0000
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8907, F1 Class 0: 0.8451, F1 Class 1: 0.9156
#
# --- Train:Test = 40:60 ---
# Epoch 1/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9063, F1 Class 0: 0.8660, F1 Class 1: 0.9279
# Epoch 2/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9062, F1 Class 0: 0.8654, F1 Class 1: 0.9280
# Epoch 3/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9034, F1 Class 0: 0.8611, F1 Class 1: 0.9259
# Epoch 4/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9004, F1 Class 0: 0.8566, F1 Class 1: 0.9236
# Epoch 5/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8972, F1 Class 0: 0.8521, F1 Class 1: 0.9212
# Epoch 6/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8979, F1 Class 0: 0.8539, F1 Class 1: 0.9215
# Epoch 7/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8946, F1 Class 0: 0.8498, F1 Class 1: 0.9189
# Epoch 8/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8898, F1 Class 0: 0.8426, F1 Class 1: 0.9152
# Epoch 9/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8915, F1 Class 0: 0.8444, F1 Class 1: 0.9167
# Epoch 10/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8973, F1 Class 0: 0.8529, F1 Class 1: 0.9211
# Epoch 11/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8961, F1 Class 0: 0.8508, F1 Class 1: 0.9203
# Epoch 12/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8961, F1 Class 0: 0.8512, F1 Class 1: 0.9201
# Epoch 13/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8948, F1 Class 0: 0.8493, F1 Class 1: 0.9192
# Epoch 14/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8961, F1 Class 0: 0.8513, F1 Class 1: 0.9201
# Epoch 15/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9039, F1 Class 0: 0.8626, F1 Class 1: 0.9261
# Epoch 16/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9005, F1 Class 0: 0.8582, F1 Class 1: 0.9234
# Epoch 17/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8931, F1 Class 0: 0.8489, F1 Class 1: 0.9173
# Epoch 18/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8936, F1 Class 0: 0.8489, F1 Class 1: 0.9178
# Epoch 19/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8957, F1 Class 0: 0.8515, F1 Class 1: 0.9197
# Epoch 20/20, Loss: 0.0000
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8875, F1 Class 0: 0.8409, F1 Class 1: 0.9130
#
# --- Train:Test = 50:50 ---
# Epoch 1/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9101, F1 Class 0: 0.8714, F1 Class 1: 0.9309
# Epoch 2/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9064, F1 Class 0: 0.8664, F1 Class 1: 0.9280
# Epoch 3/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9014, F1 Class 0: 0.8584, F1 Class 1: 0.9244
# Epoch 4/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9035, F1 Class 0: 0.8619, F1 Class 1: 0.9258
# Epoch 5/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8990, F1 Class 0: 0.8560, F1 Class 1: 0.9222
# Epoch 6/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8910, F1 Class 0: 0.8451, F1 Class 1: 0.9159
# Epoch 7/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8916, F1 Class 0: 0.8459, F1 Class 1: 0.9164
# Epoch 8/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8964, F1 Class 0: 0.8530, F1 Class 1: 0.9200
# Epoch 9/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8960, F1 Class 0: 0.8525, F1 Class 1: 0.9197
# Epoch 10/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8955, F1 Class 0: 0.8513, F1 Class 1: 0.9194
# Epoch 11/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.8955, F1 Class 0: 0.8513, F1 Class 1: 0.9194
# Epoch 12/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8988, F1 Class 0: 0.8561, F1 Class 1: 0.9219
# Epoch 13/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9002, F1 Class 0: 0.8591, F1 Class 1: 0.9228
# Epoch 14/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9014, F1 Class 0: 0.8612, F1 Class 1: 0.9236
# Epoch 15/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8960, F1 Class 0: 0.8535, F1 Class 1: 0.9193
# Epoch 16/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8953, F1 Class 0: 0.8520, F1 Class 1: 0.9190
# Epoch 17/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8969, F1 Class 0: 0.8539, F1 Class 1: 0.9203
# Epoch 18/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8975, F1 Class 0: 0.8548, F1 Class 1: 0.9208
# Epoch 19/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8971, F1 Class 0: 0.8544, F1 Class 1: 0.9205
# Epoch 20/20, Loss: 0.0000
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.8966, F1 Class 0: 0.8544, F1 Class 1: 0.9199
#
# --- Train:Test = 60:40 ---
# Epoch 1/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9096, F1 Class 0: 0.8710, F1 Class 1: 0.9304
# Epoch 2/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9072, F1 Class 0: 0.8672, F1 Class 1: 0.9287
# Epoch 3/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9047, F1 Class 0: 0.8632, F1 Class 1: 0.9269
# Epoch 4/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9025, F1 Class 0: 0.8602, F1 Class 1: 0.9252
# Epoch 5/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9024, F1 Class 0: 0.8615, F1 Class 1: 0.9246
# Epoch 6/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.8999, F1 Class 0: 0.8579, F1 Class 1: 0.9228
# Epoch 7/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.8997, F1 Class 0: 0.8579, F1 Class 1: 0.9225
# Epoch 8/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9056, F1 Class 0: 0.8664, F1 Class 1: 0.9271
# Epoch 9/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9026, F1 Class 0: 0.8621, F1 Class 1: 0.9247
# Epoch 10/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9033, F1 Class 0: 0.8633, F1 Class 1: 0.9252
# Epoch 11/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9036, F1 Class 0: 0.8637, F1 Class 1: 0.9255
# Epoch 12/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9063, F1 Class 0: 0.8676, F1 Class 1: 0.9275
# Epoch 13/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9063, F1 Class 0: 0.8679, F1 Class 1: 0.9274
# Epoch 14/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9115, F1 Class 0: 0.8754, F1 Class 1: 0.9314
# Epoch 15/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9106, F1 Class 0: 0.8739, F1 Class 1: 0.9308
# Epoch 16/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9090, F1 Class 0: 0.8717, F1 Class 1: 0.9295
# Epoch 17/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9089, F1 Class 0: 0.8713, F1 Class 1: 0.9295
# Epoch 18/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9100, F1 Class 0: 0.8728, F1 Class 1: 0.9304
# Epoch 19/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8757, F1 Class 1: 0.9317
# Epoch 20/20, Loss: 0.0000
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9124, F1 Class 0: 0.8765, F1 Class 1: 0.9321
#
# --- Train:Test = 70:30 ---
# Epoch 1/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Accuracy: 0.9130, F1 Class 0: 0.8761, F1 Class 1: 0.9329
# Epoch 2/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9074, F1 Class 0: 0.8674, F1 Class 1: 0.9289
# Epoch 3/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9067, F1 Class 0: 0.8671, F1 Class 1: 0.9282
# Epoch 4/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9021, F1 Class 0: 0.8610, F1 Class 1: 0.9244
# Epoch 5/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.8997, F1 Class 0: 0.8574, F1 Class 1: 0.9226
# Epoch 6/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9032, F1 Class 0: 0.8613, F1 Class 1: 0.9257
# Epoch 7/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.8948, F1 Class 0: 0.8508, F1 Class 1: 0.9188
# Epoch 8/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.8990, F1 Class 0: 0.8556, F1 Class 1: 0.9223
# Epoch 9/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9012, F1 Class 0: 0.8592, F1 Class 1: 0.9238
# Epoch 10/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9016, F1 Class 0: 0.8597, F1 Class 1: 0.9242
# Epoch 11/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9003, F1 Class 0: 0.8584, F1 Class 1: 0.9231
# Epoch 12/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9029, F1 Class 0: 0.8622, F1 Class 1: 0.9251
# Epoch 13/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9050, F1 Class 0: 0.8661, F1 Class 1: 0.9264
# Epoch 14/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9080, F1 Class 0: 0.8696, F1 Class 1: 0.9289
# Epoch 15/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9046, F1 Class 0: 0.8639, F1 Class 1: 0.9265
# Epoch 16/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9021, F1 Class 0: 0.8615, F1 Class 1: 0.9243
# Epoch 17/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9057, F1 Class 0: 0.8667, F1 Class 1: 0.9270
# Epoch 18/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9051, F1 Class 0: 0.8655, F1 Class 1: 0.9267
# Epoch 19/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9018, F1 Class 0: 0.8611, F1 Class 1: 0.9241
# Epoch 20/20, Loss: 0.0000
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9036, F1 Class 0: 0.8639, F1 Class 1: 0.9254
#
# --- Train:Test = 80:20 ---
# Epoch 1/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Accuracy: 0.9104, F1 Class 0: 0.8715, F1 Class 1: 0.9312
# Epoch 2/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8681, F1 Class 1: 0.9285
# Epoch 3/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9041, F1 Class 0: 0.8629, F1 Class 1: 0.9262
# Epoch 4/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9092, F1 Class 0: 0.8708, F1 Class 1: 0.9301
# Epoch 5/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9050, F1 Class 0: 0.8649, F1 Class 1: 0.9267
# Epoch 6/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.8991, F1 Class 0: 0.8576, F1 Class 1: 0.9219
# Epoch 7/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.8994, F1 Class 0: 0.8577, F1 Class 1: 0.9222
# Epoch 8/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9090, F1 Class 0: 0.8723, F1 Class 1: 0.9293
# Epoch 9/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9053, F1 Class 0: 0.8670, F1 Class 1: 0.9264
# Epoch 10/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9060, F1 Class 0: 0.8682, F1 Class 1: 0.9270
# Epoch 11/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9121, F1 Class 0: 0.8773, F1 Class 1: 0.9315
# Epoch 12/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9149, F1 Class 0: 0.8811, F1 Class 1: 0.9337
# Epoch 13/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8767, F1 Class 1: 0.9314
# Epoch 14/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9159, F1 Class 0: 0.8823, F1 Class 1: 0.9345
# Epoch 15/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9133, F1 Class 0: 0.8785, F1 Class 1: 0.9326
# Epoch 16/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9138, F1 Class 0: 0.8795, F1 Class 1: 0.9329
# Epoch 17/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9148, F1 Class 0: 0.8807, F1 Class 1: 0.9337
# Epoch 18/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9159, F1 Class 0: 0.8823, F1 Class 1: 0.9346
# Epoch 19/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9162, F1 Class 0: 0.8825, F1 Class 1: 0.9348
# Epoch 20/20, Loss: 0.0000
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9138, F1 Class 0: 0.8791, F1 Class 1: 0.9330
#
# --- Train:Test = 90:10 ---
# Epoch 1/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Accuracy: 0.9133, F1 Class 0: 0.8765, F1 Class 1: 0.9332
# Epoch 2/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9102, F1 Class 0: 0.8713, F1 Class 1: 0.9311
# Epoch 3/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9086, F1 Class 0: 0.8693, F1 Class 1: 0.9297
# Epoch 4/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9047, F1 Class 0: 0.8652, F1 Class 1: 0.9263
# Epoch 5/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9100, F1 Class 0: 0.8720, F1 Class 1: 0.9306
# Epoch 6/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9064, F1 Class 0: 0.8668, F1 Class 1: 0.9279
# Epoch 7/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8678, F1 Class 1: 0.9283
# Epoch 8/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9063, F1 Class 0: 0.8663, F1 Class 1: 0.9279
# Epoch 9/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9043, F1 Class 0: 0.8649, F1 Class 1: 0.9260
# Epoch 10/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9052, F1 Class 0: 0.8653, F1 Class 1: 0.9269
# Epoch 11/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9100, F1 Class 0: 0.8729, F1 Class 1: 0.9304
# Epoch 12/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9060, F1 Class 0: 0.8661, F1 Class 1: 0.9276
# Epoch 13/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.8969, F1 Class 0: 0.8551, F1 Class 1: 0.9200
# Epoch 14/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9094, F1 Class 0: 0.8722, F1 Class 1: 0.9299
# Epoch 15/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9121, F1 Class 0: 0.8756, F1 Class 1: 0.9321
# Epoch 16/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9143, F1 Class 0: 0.8793, F1 Class 1: 0.9336
# Epoch 17/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9052, F1 Class 0: 0.8655, F1 Class 1: 0.9268
# Epoch 18/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8722, F1 Class 1: 0.9295
# Epoch 19/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9105, F1 Class 0: 0.8736, F1 Class 1: 0.9307
# Epoch 20/20, Loss: 0.0000
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 10s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9075, F1 Class 0: 0.8697, F1 Class 1: 0.9283

# %%
#Save the Results to CSV
# -------- Step 5: Save results --------
results_df = pd.DataFrame(all_results)
results_df.to_csv('byol_ssl_rf_results_all_epochs.csv', index=False)
print("\nSaved results to 'byol_ssl_rf_results_all_epochs.csv'")
# Out:
# Saved results to 'byol_ssl_rf_results_all_epochs.csv'

# %%
#Visualization of Results
# Set style for plots
sns.set(style="whitegrid")
ratios_unique = results_df[['train_pct', 'test_pct']].drop_duplicates()

# Accuracy vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['accuracy'], marker='o', label=label)
plt.title("Accuracy vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()

# Loss vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['loss'], marker='o', label=label)
plt.title("Contrastive Loss vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()
