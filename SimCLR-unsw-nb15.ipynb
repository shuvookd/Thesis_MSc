# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load and Preprocess Dataset

# %%
# Load dataset
train = pd.read_parquet("/kaggle/input/d/shuvookd/unsw-nb15/UNSW_NB15_training-set.parquet")
test = pd.read_parquet("/kaggle/input/d/shuvookd/unsw-nb15/UNSW_NB15_testing-set.parquet")
df = pd.concat([train, test])

# Preprocessing: Drop irrelevant columns
df = df.drop(columns=['id', 'attack_cat'], errors='ignore')

# Encode categorical columns
cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    df[col] = pd.factorize(df[col])[0]

# Separate features and labels
X = df.drop('label', axis=1)
y = df['label']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)

# Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    X.values, y.values, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# Define SimCLR Components

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_encoder(input_dim):
    """Builds the encoder network for SimCLR."""
    inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(256, activation='swish')(inputs)
    x = layers.Dense(128, activation='swish')(x)
    projection = layers.Dense(64)(x)  # Projection head
    return models.Model(inputs, projection)

def contrastive_loss(query, key, temperature=0.07):
    """Contrastive loss function based on SimCLR."""
    query = tf.math.l2_normalize(query, axis=1)
    key = tf.math.l2_normalize(key, axis=1)
    logits = tf.matmul(query, key, transpose_b=True) / temperature
    labels = tf.zeros(logits.shape[0], dtype=tf.int32)  # Positive pairs are the first in the logits
    loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, logits)
    return tf.reduce_mean(loss)

def momentum_update(student_encoder, teacher_encoder, m=0.99):
    """Momentum update for teacher encoder."""
    for student_var, teacher_var in zip(student_encoder.variables, teacher_encoder.variables):
        teacher_var.assign(m * teacher_var + (1 - m) * student_var)

def augment_batch(X):
    """Augment the batch by applying random noise."""
    mask = (np.random.rand(*X.shape) > 0.15).astype(np.float32)
    noise = np.random.normal(0, 0.05, size=X.shape).astype(np.float32)
    return X * mask + noise

# %% [markdown]
# Train and Evaluate for Different Train-Test Splits

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Train and evaluate SimCLR with different train-test ratios
ratios = [(10,90), (20,80), (30,70), (40,60), (50,50), (60,40), (70,30), (80,20), (90,10)]
all_results = []

for train_pct, test_pct in ratios:
    print(f"\n--- Train:Test = {train_pct}:{test_pct} ---")

    # Split data according to the ratio
    X_train, X_test, y_train, y_test = train_test_split(
        X.values.astype(np.float32), y.values,
        test_size=test_pct / 100,
        stratify=y,
        random_state=42
    )

    # Initialize encoders and optimizer
    student_encoder = build_encoder(X_train.shape[1])
    teacher_encoder = build_encoder(X_train.shape[1])

    # Initialize teacher encoder weights with student encoder weights
    for s_var, t_var in zip(student_encoder.variables, teacher_encoder.variables):
        t_var.assign(s_var)

    optimizer = tf.keras.optimizers.Adam(3e-4)
    batch_size = 512
    epochs = 20
    num_samples = X_train.shape[0]

    # Train the model
    for epoch in range(epochs):
        idx = np.random.permutation(num_samples)
        X_shuffled = X_train[idx]

        for i in range(0, num_samples, batch_size):
            batch = X_shuffled[i:i + batch_size]
            if batch.shape[0] < 2:
                continue

            x_q = augment_batch(batch)
            x_k = augment_batch(batch)

            with tf.GradientTape() as tape:
                z_q = student_encoder(x_q, training=True)
                z_k = teacher_encoder(x_k, training=True)
                loss = contrastive_loss(z_q, z_k)

            grads = tape.gradient(loss, student_encoder.trainable_variables)
            optimizer.apply_gradients(zip(grads, student_encoder.trainable_variables))

            momentum_update(student_encoder, teacher_encoder)

        print(f"Epoch {epoch + 1}/{epochs}, Loss: {loss.numpy():.4f}")

        # Evaluate the model (Random Forest classifier on SSL embeddings)
        X_train_ssl = student_encoder.predict(X_train)
        X_test_ssl = student_encoder.predict(X_test)

        rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
        rf.fit(X_train_ssl, y_train)
        y_pred = rf.predict(X_test_ssl)
        report = classification_report(y_test, y_pred, output_dict=True)

        acc = report['accuracy']
        f1_0 = report['0']['f1-score']
        f1_1 = report['1']['f1-score']

        all_results.append({
            'train_pct': train_pct,
            'test_pct': test_pct,
            'epoch': epoch + 1,
            'loss': float(loss.numpy()),
            'accuracy': acc,
            'f1_class_0': f1_0,
            'f1_class_1': f1_1
        })

        print(f"Accuracy: {acc:.4f}, F1 Class 0: {f1_0:.4f}, F1 Class 1: {f1_1:.4f}")

# Save results to CSV file
results_df = pd.DataFrame(all_results)
results_df.to_csv('simclr_results_all_epochs.csv', index=False)
print("\nSaved results to 'simclr_results_all_epochs.csv'")
# Out:
# --- Train:Test = 10:90 ---
# Epoch 1/20, Loss: 7.2288
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9002, F1 Class 0: 0.8558, F1 Class 1: 0.9237
# Epoch 2/20, Loss: 6.8137
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.9000, F1 Class 0: 0.8555, F1 Class 1: 0.9235
# Epoch 3/20, Loss: 8.6018
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8988, F1 Class 0: 0.8538, F1 Class 1: 0.9226
# Epoch 4/20, Loss: 7.8372
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8976, F1 Class 0: 0.8520, F1 Class 1: 0.9217
# Epoch 5/20, Loss: 8.4418
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8973, F1 Class 0: 0.8515, F1 Class 1: 0.9215
# Epoch 6/20, Loss: 6.0142
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8958, F1 Class 0: 0.8494, F1 Class 1: 0.9203
# Epoch 7/20, Loss: 7.2895
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8952, F1 Class 0: 0.8489, F1 Class 1: 0.9198
# Epoch 8/20, Loss: 7.3463
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8957, F1 Class 0: 0.8492, F1 Class 1: 0.9203
# Epoch 9/20, Loss: 5.9013
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8956, F1 Class 0: 0.8497, F1 Class 1: 0.9200
# Epoch 10/20, Loss: 5.5236
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8913, F1 Class 0: 0.8431, F1 Class 1: 0.9168
# Epoch 11/20, Loss: 7.2450
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8943, F1 Class 0: 0.8469, F1 Class 1: 0.9193
# Epoch 12/20, Loss: 7.9829
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8936, F1 Class 0: 0.8465, F1 Class 1: 0.9186
# Epoch 13/20, Loss: 7.1369
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8932, F1 Class 0: 0.8454, F1 Class 1: 0.9184
# Epoch 14/20, Loss: 8.8724
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8951, F1 Class 0: 0.8479, F1 Class 1: 0.9199
# Epoch 15/20, Loss: 9.2665
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8938, F1 Class 0: 0.8468, F1 Class 1: 0.9188
# Epoch 16/20, Loss: 11.4561
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8921, F1 Class 0: 0.8442, F1 Class 1: 0.9175
# Epoch 17/20, Loss: 11.3024
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8919, F1 Class 0: 0.8441, F1 Class 1: 0.9173
# Epoch 18/20, Loss: 10.5607
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8932, F1 Class 0: 0.8459, F1 Class 1: 0.9183
# Epoch 19/20, Loss: 10.9954
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8919, F1 Class 0: 0.8444, F1 Class 1: 0.9172
# Epoch 20/20, Loss: 9.7170
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# Accuracy: 0.8918, F1 Class 0: 0.8438, F1 Class 1: 0.9172
#
# --- Train:Test = 20:80 ---
# Epoch 1/20, Loss: 6.5381
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9046, F1 Class 0: 0.8632, F1 Class 1: 0.9268
# Epoch 2/20, Loss: 7.3242
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9015, F1 Class 0: 0.8582, F1 Class 1: 0.9245
# Epoch 3/20, Loss: 6.6098
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9006, F1 Class 0: 0.8570, F1 Class 1: 0.9238
# Epoch 4/20, Loss: 7.3907
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9011, F1 Class 0: 0.8575, F1 Class 1: 0.9242
# Epoch 5/20, Loss: 8.4565
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9006, F1 Class 0: 0.8573, F1 Class 1: 0.9238
# Epoch 6/20, Loss: 8.4133
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9003, F1 Class 0: 0.8565, F1 Class 1: 0.9236
# Epoch 7/20, Loss: 9.9636
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8997, F1 Class 0: 0.8556, F1 Class 1: 0.9232
# Epoch 8/20, Loss: 9.3876
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.9007, F1 Class 0: 0.8570, F1 Class 1: 0.9239
# Epoch 9/20, Loss: 11.7344
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8976, F1 Class 0: 0.8523, F1 Class 1: 0.9216
# Epoch 10/20, Loss: 11.6793
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8965, F1 Class 0: 0.8511, F1 Class 1: 0.9207
# Epoch 11/20, Loss: 11.6609
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8950, F1 Class 0: 0.8490, F1 Class 1: 0.9195
# Epoch 12/20, Loss: 12.8169
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8965, F1 Class 0: 0.8511, F1 Class 1: 0.9207
# Epoch 13/20, Loss: 12.2698
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8941, F1 Class 0: 0.8484, F1 Class 1: 0.9187
# Epoch 14/20, Loss: 12.4343
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8968, F1 Class 0: 0.8521, F1 Class 1: 0.9207
# Epoch 15/20, Loss: 7.0222
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8984, F1 Class 0: 0.8538, F1 Class 1: 0.9221
# Epoch 16/20, Loss: 6.0227
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8987, F1 Class 0: 0.8543, F1 Class 1: 0.9224
# Epoch 17/20, Loss: 5.9793
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8982, F1 Class 0: 0.8534, F1 Class 1: 0.9220
# Epoch 18/20, Loss: 5.8842
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8991, F1 Class 0: 0.8549, F1 Class 1: 0.9226
# Epoch 19/20, Loss: 5.7739
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8987, F1 Class 0: 0.8544, F1 Class 1: 0.9224
# Epoch 20/20, Loss: 5.8071
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# Accuracy: 0.8980, F1 Class 0: 0.8533, F1 Class 1: 0.9218
#
# --- Train:Test = 30:70 ---
# Epoch 1/20, Loss: 6.9466
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8644, F1 Class 1: 0.9273
# Epoch 2/20, Loss: 7.7889
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9020, F1 Class 0: 0.8592, F1 Class 1: 0.9249
# Epoch 3/20, Loss: 7.4861
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9018, F1 Class 0: 0.8588, F1 Class 1: 0.9248
# Epoch 4/20, Loss: 9.2992
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9018, F1 Class 0: 0.8589, F1 Class 1: 0.9247
# Epoch 5/20, Loss: 11.4266
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8990, F1 Class 0: 0.8552, F1 Class 1: 0.9224
# Epoch 6/20, Loss: 10.6924
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9006, F1 Class 0: 0.8572, F1 Class 1: 0.9238
# Epoch 7/20, Loss: 10.8631
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9010, F1 Class 0: 0.8576, F1 Class 1: 0.9242
# Epoch 8/20, Loss: 14.1382
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8993, F1 Class 0: 0.8553, F1 Class 1: 0.9228
# Epoch 9/20, Loss: 14.2281
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9009, F1 Class 0: 0.8578, F1 Class 1: 0.9240
# Epoch 10/20, Loss: 10.3989
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8995, F1 Class 0: 0.8557, F1 Class 1: 0.9229
# Epoch 11/20, Loss: 6.2839
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8991, F1 Class 0: 0.8550, F1 Class 1: 0.9227
# Epoch 12/20, Loss: 6.5362
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.9005, F1 Class 0: 0.8565, F1 Class 1: 0.9238
# Epoch 13/20, Loss: 6.2467
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8981, F1 Class 0: 0.8533, F1 Class 1: 0.9219
# Epoch 14/20, Loss: 6.2264
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8978, F1 Class 0: 0.8530, F1 Class 1: 0.9217
# Epoch 15/20, Loss: 6.2200
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8982, F1 Class 0: 0.8536, F1 Class 1: 0.9220
# Epoch 16/20, Loss: 6.2141
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8979, F1 Class 0: 0.8531, F1 Class 1: 0.9218
# Epoch 17/20, Loss: 6.2144
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8976, F1 Class 0: 0.8527, F1 Class 1: 0.9215
# Epoch 18/20, Loss: 6.2309
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8981, F1 Class 0: 0.8534, F1 Class 1: 0.9219
# Epoch 19/20, Loss: 6.1966
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8980, F1 Class 0: 0.8533, F1 Class 1: 0.9218
# Epoch 20/20, Loss: 6.2099
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# Accuracy: 0.8980, F1 Class 0: 0.8532, F1 Class 1: 0.9218
#
# --- Train:Test = 40:60 ---
# Epoch 1/20, Loss: 6.6730
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9050, F1 Class 0: 0.8636, F1 Class 1: 0.9271
# Epoch 2/20, Loss: 6.1507
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9026, F1 Class 0: 0.8599, F1 Class 1: 0.9254
# Epoch 3/20, Loss: 9.2672
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9044, F1 Class 0: 0.8634, F1 Class 1: 0.9264
# Epoch 4/20, Loss: 10.0153
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9033, F1 Class 0: 0.8613, F1 Class 1: 0.9257
# Epoch 5/20, Loss: 13.7684
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9010, F1 Class 0: 0.8581, F1 Class 1: 0.9240
# Epoch 6/20, Loss: 11.8768
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9020, F1 Class 0: 0.8594, F1 Class 1: 0.9248
# Epoch 7/20, Loss: 8.3601
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9037, F1 Class 0: 0.8616, F1 Class 1: 0.9261
# Epoch 8/20, Loss: 5.4733
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9035, F1 Class 0: 0.8615, F1 Class 1: 0.9259
# Epoch 9/20, Loss: 5.1310
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9039, F1 Class 0: 0.8620, F1 Class 1: 0.9262
# Epoch 10/20, Loss: 5.1222
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9037, F1 Class 0: 0.8619, F1 Class 1: 0.9261
# Epoch 11/20, Loss: 5.0535
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9029, F1 Class 0: 0.8605, F1 Class 1: 0.9256
# Epoch 12/20, Loss: 5.0539
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9027, F1 Class 0: 0.8602, F1 Class 1: 0.9254
# Epoch 13/20, Loss: 5.0570
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9037, F1 Class 0: 0.8618, F1 Class 1: 0.9261
# Epoch 14/20, Loss: 5.0512
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9028, F1 Class 0: 0.8605, F1 Class 1: 0.9255
# Epoch 15/20, Loss: 5.0441
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9036, F1 Class 0: 0.8616, F1 Class 1: 0.9261
# Epoch 16/20, Loss: 5.0468
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9029, F1 Class 0: 0.8606, F1 Class 1: 0.9255
# Epoch 17/20, Loss: 5.0789
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9028, F1 Class 0: 0.8603, F1 Class 1: 0.9255
# Epoch 18/20, Loss: 5.0496
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9031, F1 Class 0: 0.8606, F1 Class 1: 0.9257
# Epoch 19/20, Loss: 5.0541
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9036, F1 Class 0: 0.8615, F1 Class 1: 0.9261
# Epoch 20/20, Loss: 5.0459
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Accuracy: 0.9030, F1 Class 0: 0.8607, F1 Class 1: 0.9256
#
# --- Train:Test = 50:50 ---
# Epoch 1/20, Loss: 6.9633
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9094, F1 Class 0: 0.8703, F1 Class 1: 0.9304
# Epoch 2/20, Loss: 8.1174
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9071, F1 Class 0: 0.8666, F1 Class 1: 0.9288
# Epoch 3/20, Loss: 11.2431
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9053, F1 Class 0: 0.8644, F1 Class 1: 0.9273
# Epoch 4/20, Loss: 10.9798
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9039, F1 Class 0: 0.8623, F1 Class 1: 0.9263
# Epoch 5/20, Loss: 12.5308
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9048, F1 Class 0: 0.8634, F1 Class 1: 0.9270
# Epoch 6/20, Loss: 8.1441
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9051, F1 Class 0: 0.8642, F1 Class 1: 0.9271
# Epoch 7/20, Loss: 5.9271
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8648, F1 Class 1: 0.9273
# Epoch 8/20, Loss: 5.7917
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9062, F1 Class 0: 0.8658, F1 Class 1: 0.9279
# Epoch 9/20, Loss: 5.7650
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9051, F1 Class 0: 0.8641, F1 Class 1: 0.9271
# Epoch 10/20, Loss: 5.7752
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8645, F1 Class 1: 0.9273
# Epoch 11/20, Loss: 5.7713
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9059, F1 Class 0: 0.8655, F1 Class 1: 0.9276
# Epoch 12/20, Loss: 5.7750
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9057, F1 Class 0: 0.8653, F1 Class 1: 0.9275
# Epoch 13/20, Loss: 5.7679
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9061, F1 Class 0: 0.8656, F1 Class 1: 0.9278
# Epoch 14/20, Loss: 5.7720
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8647, F1 Class 1: 0.9273
# Epoch 15/20, Loss: 5.7699
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9059, F1 Class 0: 0.8653, F1 Class 1: 0.9277
# Epoch 16/20, Loss: 5.7672
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9057, F1 Class 0: 0.8650, F1 Class 1: 0.9276
# Epoch 17/20, Loss: 5.7720
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9057, F1 Class 0: 0.8650, F1 Class 1: 0.9275
# Epoch 18/20, Loss: 5.7680
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9053, F1 Class 0: 0.8646, F1 Class 1: 0.9272
# Epoch 19/20, Loss: 5.7760
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8647, F1 Class 1: 0.9273
# Epoch 20/20, Loss: 5.7657
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# 4027/4027 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
# Accuracy: 0.9055, F1 Class 0: 0.8647, F1 Class 1: 0.9274
#
# --- Train:Test = 60:40 ---
# Epoch 1/20, Loss: 8.1878
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9083, F1 Class 0: 0.8687, F1 Class 1: 0.9296
# Epoch 2/20, Loss: 10.3278
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9068, F1 Class 0: 0.8661, F1 Class 1: 0.9286
# Epoch 3/20, Loss: 10.2999
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9041, F1 Class 0: 0.8622, F1 Class 1: 0.9265
# Epoch 4/20, Loss: 13.6318
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9051, F1 Class 0: 0.8635, F1 Class 1: 0.9273
# Epoch 5/20, Loss: 10.6344
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9037, F1 Class 0: 0.8619, F1 Class 1: 0.9261
# Epoch 6/20, Loss: 6.2644
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9033, F1 Class 0: 0.8609, F1 Class 1: 0.9259
# Epoch 7/20, Loss: 6.1873
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9028, F1 Class 0: 0.8602, F1 Class 1: 0.9255
# Epoch 8/20, Loss: 6.2077
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9032, F1 Class 0: 0.8608, F1 Class 1: 0.9258
# Epoch 9/20, Loss: 6.1936
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9027, F1 Class 0: 0.8602, F1 Class 1: 0.9253
# Epoch 10/20, Loss: 6.2024
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9025, F1 Class 0: 0.8599, F1 Class 1: 0.9252
# Epoch 11/20, Loss: 6.1857
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9026, F1 Class 0: 0.8600, F1 Class 1: 0.9253
# Epoch 12/20, Loss: 6.1782
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9023, F1 Class 0: 0.8596, F1 Class 1: 0.9251
# Epoch 13/20, Loss: 6.1853
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9029, F1 Class 0: 0.8604, F1 Class 1: 0.9255
# Epoch 14/20, Loss: 6.2241
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9027, F1 Class 0: 0.8600, F1 Class 1: 0.9254
# Epoch 15/20, Loss: 6.1834
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9025, F1 Class 0: 0.8600, F1 Class 1: 0.9252
# Epoch 16/20, Loss: 6.2052
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9015, F1 Class 0: 0.8583, F1 Class 1: 0.9245
# Epoch 17/20, Loss: 6.1957
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9020, F1 Class 0: 0.8591, F1 Class 1: 0.9249
# Epoch 18/20, Loss: 6.1985
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9020, F1 Class 0: 0.8590, F1 Class 1: 0.9248
# Epoch 19/20, Loss: 6.1791
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9025, F1 Class 0: 0.8598, F1 Class 1: 0.9253
# Epoch 20/20, Loss: 6.1977
# 4832/4832 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# 3221/3221 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# Accuracy: 0.9020, F1 Class 0: 0.8590, F1 Class 1: 0.9249
#
# --- Train:Test = 70:30 ---
# Epoch 1/20, Loss: 7.2614
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9085, F1 Class 0: 0.8694, F1 Class 1: 0.9296
# Epoch 2/20, Loss: 9.8287
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9066, F1 Class 0: 0.8667, F1 Class 1: 0.9281
# Epoch 3/20, Loss: 13.6603
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9052, F1 Class 0: 0.8641, F1 Class 1: 0.9272
# Epoch 4/20, Loss: 11.5686
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9056, F1 Class 0: 0.8651, F1 Class 1: 0.9273
# Epoch 5/20, Loss: 5.2974
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9057, F1 Class 0: 0.8649, F1 Class 1: 0.9276
# Epoch 6/20, Loss: 5.0589
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9059, F1 Class 0: 0.8652, F1 Class 1: 0.9277
# Epoch 7/20, Loss: 4.9919
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9051, F1 Class 0: 0.8641, F1 Class 1: 0.9271
# Epoch 8/20, Loss: 5.0046
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9054, F1 Class 0: 0.8646, F1 Class 1: 0.9274
# Epoch 9/20, Loss: 4.9882
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9055, F1 Class 0: 0.8648, F1 Class 1: 0.9274
# Epoch 10/20, Loss: 4.9872
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9058, F1 Class 0: 0.8652, F1 Class 1: 0.9276
# Epoch 11/20, Loss: 4.9824
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9061, F1 Class 0: 0.8654, F1 Class 1: 0.9279
# Epoch 12/20, Loss: 4.9762
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9068, F1 Class 0: 0.8665, F1 Class 1: 0.9284
# Epoch 13/20, Loss: 4.9873
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9063, F1 Class 0: 0.8658, F1 Class 1: 0.9280
# Epoch 14/20, Loss: 4.9877
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9057, F1 Class 0: 0.8650, F1 Class 1: 0.9275
# Epoch 15/20, Loss: 4.9917
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9053, F1 Class 0: 0.8645, F1 Class 1: 0.9273
# Epoch 16/20, Loss: 4.9820
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9052, F1 Class 0: 0.8640, F1 Class 1: 0.9272
# Epoch 17/20, Loss: 4.9852
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9060, F1 Class 0: 0.8653, F1 Class 1: 0.9278
# Epoch 18/20, Loss: 4.9847
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9061, F1 Class 0: 0.8656, F1 Class 1: 0.9278
# Epoch 19/20, Loss: 4.9944
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9052, F1 Class 0: 0.8644, F1 Class 1: 0.9272
# Epoch 20/20, Loss: 5.0003
# 5637/5637 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 2416/2416 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# Accuracy: 0.9065, F1 Class 0: 0.8662, F1 Class 1: 0.9282
#
# --- Train:Test = 80:20 ---
# Epoch 1/20, Loss: 7.9813
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9105, F1 Class 0: 0.8721, F1 Class 1: 0.9312
# Epoch 2/20, Loss: 12.2800
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9123, F1 Class 0: 0.8748, F1 Class 1: 0.9325
# Epoch 3/20, Loss: 15.3265
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9082, F1 Class 0: 0.8684, F1 Class 1: 0.9295
# Epoch 4/20, Loss: 6.1481
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9087, F1 Class 0: 0.8695, F1 Class 1: 0.9298
# Epoch 5/20, Loss: 5.7632
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9101, F1 Class 0: 0.8714, F1 Class 1: 0.9309
# Epoch 6/20, Loss: 5.7412
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9094, F1 Class 0: 0.8704, F1 Class 1: 0.9304
# Epoch 7/20, Loss: 5.7479
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9092, F1 Class 0: 0.8701, F1 Class 1: 0.9302
# Epoch 8/20, Loss: 5.7321
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9092, F1 Class 0: 0.8701, F1 Class 1: 0.9302
# Epoch 9/20, Loss: 5.7396
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9082, F1 Class 0: 0.8685, F1 Class 1: 0.9295
# Epoch 10/20, Loss: 5.7405
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8698, F1 Class 1: 0.9302
# Epoch 11/20, Loss: 5.7457
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9099, F1 Class 0: 0.8710, F1 Class 1: 0.9307
# Epoch 12/20, Loss: 5.7429
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9098, F1 Class 0: 0.8710, F1 Class 1: 0.9306
# Epoch 13/20, Loss: 5.7392
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9096, F1 Class 0: 0.8707, F1 Class 1: 0.9305
# Epoch 14/20, Loss: 5.7392
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9098, F1 Class 0: 0.8710, F1 Class 1: 0.9306
# Epoch 15/20, Loss: 5.7354
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9095, F1 Class 0: 0.8705, F1 Class 1: 0.9305
# Epoch 16/20, Loss: 5.7463
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9091, F1 Class 0: 0.8700, F1 Class 1: 0.9301
# Epoch 17/20, Loss: 5.7336
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9088, F1 Class 0: 0.8695, F1 Class 1: 0.9300
# Epoch 18/20, Loss: 5.7417
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8677, F1 Class 1: 0.9290
# Epoch 19/20, Loss: 5.7776
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9076, F1 Class 0: 0.8678, F1 Class 1: 0.9290
# Epoch 20/20, Loss: 5.7347
# 6442/6442 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 1611/1611 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Accuracy: 0.9073, F1 Class 0: 0.8674, F1 Class 1: 0.9288
#
# --- Train:Test = 90:10 ---
# Epoch 1/20, Loss: 7.2364
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9113, F1 Class 0: 0.8732, F1 Class 1: 0.9318
# Epoch 2/20, Loss: 13.4560
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8740, F1 Class 1: 0.9321
# Epoch 3/20, Loss: 12.6100
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9111, F1 Class 0: 0.8725, F1 Class 1: 0.9317
# Epoch 4/20, Loss: 8.4167
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9095, F1 Class 0: 0.8700, F1 Class 1: 0.9305
# Epoch 5/20, Loss: 6.1902
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9116, F1 Class 0: 0.8735, F1 Class 1: 0.9321
# Epoch 6/20, Loss: 6.1733
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9104, F1 Class 0: 0.8718, F1 Class 1: 0.9311
# Epoch 7/20, Loss: 6.1752
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9117, F1 Class 0: 0.8737, F1 Class 1: 0.9321
# Epoch 8/20, Loss: 6.1600
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9108, F1 Class 0: 0.8722, F1 Class 1: 0.9315
# Epoch 9/20, Loss: 6.1624
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9116, F1 Class 0: 0.8737, F1 Class 1: 0.9320
# Epoch 10/20, Loss: 6.1665
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9110, F1 Class 0: 0.8726, F1 Class 1: 0.9316
# Epoch 11/20, Loss: 6.1637
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9124, F1 Class 0: 0.8745, F1 Class 1: 0.9327
# Epoch 12/20, Loss: 6.2236
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9103, F1 Class 0: 0.8715, F1 Class 1: 0.9311
# Epoch 13/20, Loss: 6.1617
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9118, F1 Class 0: 0.8738, F1 Class 1: 0.9322
# Epoch 14/20, Loss: 6.1635
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9114, F1 Class 0: 0.8737, F1 Class 1: 0.9318
# Epoch 15/20, Loss: 6.1760
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9101, F1 Class 0: 0.8714, F1 Class 1: 0.9309
# Epoch 16/20, Loss: 6.1777
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9120, F1 Class 0: 0.8741, F1 Class 1: 0.9324
# Epoch 17/20, Loss: 6.1593
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9124, F1 Class 0: 0.8748, F1 Class 1: 0.9326
# Epoch 18/20, Loss: 6.1812
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9107, F1 Class 0: 0.8718, F1 Class 1: 0.9315
# Epoch 19/20, Loss: 6.1889
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9120, F1 Class 0: 0.8745, F1 Class 1: 0.9323
# Epoch 20/20, Loss: 6.1935
# 7248/7248 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9116, F1 Class 0: 0.8735, F1 Class 1: 0.9321
#
# Saved results to 'simclr_ssl_rf_results_all_epochs.csv'

# %% [markdown]
#  Visualize the Results

# %%
import seaborn as sns

sns.set(style="whitegrid")
ratios_unique = results_df[['train_pct', 'test_pct']].drop_duplicates()

# Accuracy vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['accuracy'], marker='o', label=label)
plt.title("Accuracy vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()

# %%
# Loss vs Epoch
plt.figure(figsize=(12, 7))
for _, row in ratios_unique.iterrows():
    subset = results_df[
        (results_df['train_pct'] == row['train_pct']) & 
        (results_df['test_pct'] == row['test_pct'])
    ]
    label = f"{int(row['train_pct'])}:{int(row['test_pct'])}"
    plt.plot(subset['epoch'], subset['loss'], marker='o', label=label)
plt.title("Contrastive Loss vs Epoch per Train:Test Ratio")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(title="Train:Test")
plt.tight_layout()
plt.show()
